# %%
#To increase cell width of ipynb
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import tensorflow as tf
from collections import defaultdict
import gzip
import cv2 as cv
import os
import numpy as np
import random
# Out:
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
class DEN():

    def __init__(self):
        self.last_label_index = 0    # tracks the label index upto which the model has been trained
        self.params = dict()
        self.k_ex = 5
        self.den_layers = 3
        self.conv_layers = 2
        tf.reset_default_graph()
        self.sess = None
        self.train = []
        self.train_labels = []
        self.test = []
        self.test_labels = []
        self.batch_size = 10
        self.epochs = 50
        self.early_stop = 5
        self.selected = dict()
        self.lr = 1e-3
        self.l2_mu = 0.001
        self.lamba_regular = 0.5
        self.l1_thr = 0.00001
#         self.l1_thr = 0.00001
        self.loss_thr = 0.01

    def extract_data(self):
        train = []
        test = []
        train_labels = []
        test_labels = []
        label_names = []
        
        # For easier disk read operation
#         VGG16
#         np_train_path = '../ModelNet40/extracted_features/VGG16/train.npy.gz'
#         np_test_path = '../ModelNet40/extracted_features/VGG16/test.npy.gz'
#         np_train_label_path = '../ModelNet40/extracted_features/VGG16/train_labels.npy'
#         np_test_label_path = '../ModelNet40/extracted_features/VGG16/test_labels.npy'
#         np_label_names_path = '../ModelNet40/extracted_features/VGG16/label_names.npy'

#       MobileNetV2
        np_train_path = '../ModelNet40/extracted_features/MobileNetV2/train.npy.gz'
        np_test_path = '../ModelNet40/extracted_features/MobileNetV2/test.npy.gz'
        np_train_label_path = '../ModelNet40/extracted_features/MobileNetV2/train_labels.npy'
        np_test_label_path = '../ModelNet40/extracted_features/MobileNetV2/test_labels.npy'
        np_label_names_path = '../ModelNet40/extracted_features/MobileNetV2/label_names.npy'
        
#       Custom MobileNetV2
#         np_train_path = '../ModelNet40/extracted_features/custom_MobileNetV2/train.npy.gz'
#         np_test_path = '../ModelNet40/extracted_features/custom_MobileNetV2/test.npy.gz'
#         np_train_label_path = '../ModelNet40/extracted_features/custom_MobileNetV2/train_labels.npy'
#         np_test_label_path = '../ModelNet40/extracted_features/custom_MobileNetV2/test_labels.npy'
#         np_label_names_path = '../ModelNet40/extracted_features/custom_MobileNetV2/label_names.npy'
        
        print("\n..........loading dataset from numpy files..........\n")

        with gzip.GzipFile(np_train_path, "r") as f:
            train = np.load(f)
        with gzip.GzipFile(np_test_path, "r") as f:
            test = np.load(f)

        train_labels = np.load(np_train_label_path)
        test_labels = np.load(np_test_label_path)
        label_names = np.load(np_label_names_path)

        return train, train_labels, test, test_labels, label_names


    def add_task(self, task_id, label_names, initial_output=2):

        new_label_indices = []
        self.train = []
        self.train_labels = []
        self.train_ex_labels = []      
 
        if task_id == 1:
            self.new_train = []
            self.new_train_labels = []
            self.new_train_ex_labels = []
            self.total = []
            self.total_ex_labels = []
            self.test = []
            self.test_labels = []
            for i in range(initial_output):   # By default, first task is a binary classification
                new_label_indices.append(i)
            self.last_label_index = i

        else:
            new_label_indices.append(self.last_label_index+1)
            self.last_label_index = self.last_label_index + 1
            
            #saving the old training data
            self.total = self.total + self.new_train
            self.total_ex_labels = self.total_ex_labels + self.new_train_ex_labels
            self.new_train = []
            self.new_train_labels = []
            self.new_train_ex_labels = []

        for index in new_label_indices:
            print(" \n Added new category: "+str(label_names[index]))
            l = 1 if task_id != 1 else index
            for data, label in zip(train_data, train_labels):
                if label_names[index] == label:
                    self.new_train.append(data)
                    self.new_train_labels.append(l)
                    self.new_train_ex_labels.append(index)
#                 if len(self.new_train_labels) >= 300:
#                     break

            for data, label in zip(test_data, test_labels):
                if label_names[index] == label:
                    self.test.append(data)
                    self.test_labels.append(index)
                    
        # ------------------ Random sampling old training data ------------------
#         if task_id != 1:
#             sampled_indices = random.sample(range(len(self.total)), len(self.new_train))
#             for k in sampled_indices:
#                 self.train.append(self.total[k])
#                 self.train_labels.append(0)
#                 self.train_ex_labels.append(self.total_ex_labels[k])
                
#             self.train = self.train + self.new_train
#             self.train_labels = self.train_labels + self.new_train_labels
#             self.train_ex_labels = self.train_ex_labels + self.new_train_ex_labels
#         else:
#             self.train = self.new_train
#             self.train_labels = self.new_train_labels
#             self.train_ex_labels = self.new_train_ex_labels
        
        # ------------------- Memory Replay of old training data ----------------------
        if task_id != 1:
            sample_per_label = int(len(self.new_train) / self.last_label_index)
            if sample_per_label < 20:
                sample_per_label = 20
                
            for index in range(self.last_label_index):
                label_indices = []
                for i, m in enumerate(self.total_ex_labels):
                    if m == index:
                        label_indices.append(i)
                try:
                    sampled_label_indices = random.sample(label_indices, k=sample_per_label)
                except:
                    print("\n Less samples; so taking them all")
                    sampled_label_indices = label_indices
                for k in sampled_label_indices:
                    self.train.append(self.total[k])
                    self.train_labels.append(0)
                    self.train_ex_labels.append(self.total_ex_labels[k])
                    
            self.train = self.train + self.new_train
            self.train_labels = self.train_labels + self.new_train_labels
            self.train_ex_labels = self.train_ex_labels + self.new_train_ex_labels

        else:
            self.train = self.new_train
            self.train_labels = self.new_train_labels
            self.train_ex_labels = self.new_train_ex_labels
        
        print("Train size: %d" %len(self.train_ex_labels))
        print("Test size: %d" %len(self.test_labels))
            

    def destroy_graph(self):
        tf.reset_default_graph()
        self.params = dict()

    def initialize_parameters(self, output_len=2):
        self.sess = tf.Session()
#       MobileNetV2 :-
        self.x = tf.placeholder(tf.float32, [None, 1280])
#       VGG16 :-
#         self.x = tf.placeholder(tf.float32, [None, 4 * 4 * 512])
        self.y_ = tf.placeholder(tf.float32, [None, output_len])
        # self.keep_prob = tf.placeholder(tf.float32)          # dropout probability

    def create_variable(self, name=None, shape=None, scope=None, trainable=True):
        with tf.variable_scope(scope, reuse=False):
            w = tf.get_variable(name, shape=shape, 
#                                 initializer=tf.random_normal_initializer(mean=0, stddev=1, seed=3),
                                trainable=trainable)
            if "ex" not in name:
                self.params[w.name] = w
        return w

    def get_variable(self, name=None, scope=None):
        with tf.variable_scope(scope, reuse=True):
            w = tf.get_variable(name)
            if "ex" not in name:
                self.params[w.name] = w
        return w

    def restore_params(self, task_id=None, trainable=True, param_values=dict()):
        self.params = dict()
        self.prev_W = dict()
        for scope_name, value in param_values.items():
            self.prev_W[scope_name] = value
            scope_name = scope_name.split(':')[0]
            [scope, name] = scope_name.split('/')

#             if task_id != None:
#                 if ('l%d/w_%d' % (self.den_layers,task_id) in scope_name) or ('l%d/b_%d' % (self.den_layers,task_id) in scope_name):
#                     trainable = True
#                 else:
#                     trainable = False

            with tf.variable_scope(scope, reuse=False):
                w = tf.get_variable(name, initializer=value, trainable=trainable)
            self.params[w.name] = w

    def get_params(self):
        vdict = dict()
        for scope_name, ref_w in self.params.items():
            vdict[scope_name] = self.sess.run(ref_w)
        return vdict

    def conv2d(self, x, W):
        return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

    def max_pool_2x2(self, x):
        return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                            strides=[1, 2, 2, 1], padding='SAME')


    def build_model(self, task_id, expansion=False, output_len=2):

        # Note: scope and name values are only given to DEN layers, not for fixed sized layers.

        self.initialize_parameters(output_len)

        if task_id == 1:

            #flattened first fc layer
            W_fc1 = self.create_variable(name="w", shape=[1280, 1024], scope="l1")   # (MobileNetV2) layer-1 outgoing weight matrix
#             W_fc1 = self.create_variable(name="w", shape=[4 * 4 * 512, 1024], scope="l1")   # (VGG16) layer-1 outgoing weight matrix
            b_fc1 = self.create_variable(name="b", shape=[1024], scope="l1")

            h_fc1 = tf.nn.relu(tf.matmul(self.x, W_fc1) + b_fc1)

            #second fc layer
            W_fc2 = self.create_variable(name="w", shape=[1024, 256], scope="l2")   # layer-2 outgoing weight matrix
            b_fc2 = self.create_variable(name="b", shape=[256], scope="l2")

            self.h_fc2 = tf.nn.relu(tf.matmul(h_fc1, W_fc2) + b_fc2)

            # readout fc layer
            self.w_fc = self.create_variable(name="w", shape=[256, output_len], scope="l3")     # layer-3 outgoing weight matrix 
            self.b_fc = self.create_variable(name="b", shape=[output_len], scope="l3")
            y_conv = tf.matmul(self.h_fc2, self.w_fc) + self.b_fc
            
        elif expansion:
            
            # fc layer expansion
            for layer in range(1, self.den_layers+1):

                if layer == 1:
                    w_fc1 = self.get_variable(name="w", scope="l%d"%layer)
                    b_fc1 = self.get_variable(name="b", scope="l%d"%layer)

                    w_expand = self.create_variable(name="w_ex_"+str(task_id),shape=[w_fc1.get_shape().as_list()[0], self.k_ex], scope="l"+str(layer))
                    b_expand = self.create_variable(name="b_ex_"+str(task_id),shape=[self.k_ex], scope="l%d"%layer)
                    w_expanded = tf.concat([w_fc1,w_expand],1)
                    b_expanded = tf.concat([b_fc1,b_expand],0)
                    self.params[w_fc1.name] = w_expanded
                    self.params[b_fc1.name] = b_expanded
                    h_fc1 = tf.nn.relu(tf.matmul(self.x, w_expanded) + b_expanded)

                elif layer == self.den_layers:
                    #weight matrix of current task output
                    w_fc3 = self.get_variable(name="w",scope="l%d"%layer)
                    b_fc3 = self.get_variable(name="b",scope="l%d"%layer)
                    next_dim = w_fc3.get_shape().as_list()[1]
                    
                    w_expand = self.create_variable(name="w_ex_"+str(task_id), shape=[self.k_ex, next_dim], scope="l%d"%layer)
                    w_expanded = tf.concat([w_fc3, w_expand], 0)
                    
                    self.params[w_fc3.name] = w_expanded
                    
                    y_conv = tf.matmul(self.h_fc2, w_expanded) + b_fc3

                else:
                    w_fc2 = self.get_variable(name="w",scope="l%d"%layer)
                    b_fc2 = self.get_variable(name="b",scope="l%d"%layer)

                    prev_dim = w_fc2.get_shape().as_list()[0]
                    next_dim = w_fc2.get_shape().as_list()[1]
                    
                    # Dummy nodes for prev hidden nodes
                    dummy_w = tf.get_variable(name="dummy_t%d_l%d" %(task_id,layer), shape=[self.k_ex, next_dim], 
                                initializer=tf.constant_initializer(0.0), trainable=False)

                    w_expand = self.create_variable(name="w_ex_"+str(task_id), shape=[prev_dim + self.k_ex, self.k_ex], scope="l%d"%layer)
                    b_expand = self.create_variable(name="b_ex_"+str(task_id), shape=[self.k_ex], scope="l%d"%layer)
                    
                    w_fc2_dummy = tf.concat([w_fc2, dummy_w],0)
                    
                    w_expanded = tf.concat([w_fc2_dummy, w_expand], 1)
                    b_expanded = tf.concat([b_fc2, b_expand], 0)
                    
                    self.params[w_fc2.name] = w_expanded
                    self.params[b_fc2.name] = b_expanded
                    self.h_fc2 = tf.nn.relu(tf.matmul(h_fc1, w_expanded) + b_expanded)
                    
        else:

            #flattened first fc layer
            W_fc1 = self.get_variable(name="w", scope="l1")   # layer-1 outgoing weight matrix
            b_fc1 = self.get_variable(name="b", scope="l1")

            h_fc1 = tf.nn.relu(tf.matmul(self.x, W_fc1) + b_fc1)

            #second fc layer
            W_fc2 = self.get_variable(name="w", scope="l2")   # layer-2 outgoing weight matrix
            b_fc2 = self.get_variable(name="b", scope="l2")

            self.h_fc2 = tf.nn.relu(tf.matmul(h_fc1, W_fc2) + b_fc2)

            self.w_fc = self.create_variable(name="w_"+str(task_id), shape=[self.h_fc2.shape[1], output_len], scope="l3", trainable=True)     # layer-3 outgoing weight matrix 
            self.b_fc = self.create_variable(name="b_"+str(task_id), shape=[output_len], scope="l3", trainable=True)
            y_conv = tf.matmul(self.h_fc2, self.w_fc) + self.b_fc

#         y_conv = tf.nn.sigmoid(y_conv)
        return y_conv
    
    def perform_selection(self, task_id, values_dict):      # Breadth first search for selecting non-zero units
        
        all_indices = defaultdict(list)     # to store indices of nonzero units
        selected_params = dict()            # to store values of nonzero units
        selected_prev_params = dict()
        
#         for scope, value in values_dict.items():    # Storing conv layers in selected parameters 
#             if "conv" in scope:
#                 selected_params[scope] = value
            
        for i in reversed(range(1,self.den_layers+1)):
            if i == self.den_layers:
                w = values_dict['l%d/w:0' % i]
                b = values_dict['l%d/b:0' % i]
                w_t = values_dict['l%d/w_%d:0' %(i,task_id)]
                b_t = values_dict['l%d/b_%d:0' %(i,task_id)]
                w = np.concatenate((w, w_t), 1)
                b = np.concatenate((b, b_t), 0)
                for j in range(w.shape[0]):
                    if w[j,-1] != 0.0:
                        all_indices['l%d' % i].append(j)
                # np.ix_(): fancy indexing, index with arrays of integers
                # Select non-zero weights between the last hidden layer and the output layer
                selected_params['l%d/w_%d:0' % (i, task_id)] = \
                    w[np.ix_(all_indices['l%d' % i], list(range(w.shape[1])))]
                selected_params['l%d/b_%d:0' % (i, task_id)] = b
            else:
                w = values_dict['l%d/w:0' % i]
                b = values_dict['l%d/b:0' % i]
                top_indices = all_indices['l%d' % (i + 1)]
                print("Layer %d: Selecting %d neurons" %(i+1, len(top_indices)))
                for j in range(w.shape[0]):
                    if np.count_nonzero(w[j, top_indices]) != 0 or i == 1:
                        all_indices['l%d' % i].append(j)
                
                # non-zero weights between the layer i and the layer i+1
                sub_weight = w[np.ix_(all_indices['l%d' % i], top_indices)]
                sub_biases = b[all_indices['l%d' % (i + 1)]]
                selected_params['l%d/w:0' % i] = sub_weight
                selected_params['l%d/b:0' % i] = sub_biases
                
                # prev_W : to avoid drastic change in value of weights (Regularization)
                selected_prev_params['l%d/w:0' % i] = \
                    self.prev_W['l%d/w:0' % i][np.ix_(all_indices['l%d' % i], top_indices)]
                selected_prev_params['l%d/b:0' % i] = \
                    self.prev_W['l%d/b:0' % i][all_indices['l%d' % (i + 1)]]

#         for keys, value in selected_params.items():
#             print(keys)
#             print(value)
                
        return [selected_params, selected_prev_params, all_indices]
        
    def build_SR(self, task_id, selected, output_len):    # creating selective retraining model
        
        self.initialize_parameters(output_len)
        h = self.x
        
        for i in range(1, self.den_layers):
            with tf.variable_scope('l%d' % i):
                w = tf.get_variable('w', initializer=selected['l%d/w:0' % i], trainable=True)
                b = tf.get_variable('b', initializer=selected['l%d/b:0' % i], trainable=True)
            h = tf.nn.relu(tf.matmul(h, w) + b)
            
        # last layer
        with tf.variable_scope('l%d' % self.den_layers):
            w = tf.get_variable('w_%d' % task_id,
                                initializer=selected['l%d/w_%d:0' % (self.den_layers, task_id)], trainable=True)
            b = tf.get_variable('b_%d' % task_id,
                                initializer=selected['l%d/b_%d:0' % (self.den_layers, task_id)], trainable=True)

        y_conv = tf.matmul(h, w) + b
#         y_conv = tf.nn.sigmoid(y_conv)
        return y_conv

    def optimization(self, prev_W=None):

        l2_regular = 0
        train_var = []
        regular_terms = []
        
        self.loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=self.y_, logits=y_conv))

#         for var in tf.trainable_variables():
#             l2_regular = l2_regular + tf.nn.l1_loss(var)
#             train_var.append(var)
#         print(len(train_var))

        l1_var = [var for var in tf.trainable_variables()]
        regularizer = tf.contrib.layers.l1_regularizer(self.l2_mu)
        reg_term = tf.contrib.layers.apply_regularization(regularizer, l1_var)
        self.loss = self.loss + reg_term
#         self.loss = self.loss + tf.reduce_mean(self.l2_mu * l2_regular)

        if prev_W != None:
            for var in l1_var:
                if var.name in prev_W.keys():
                    prev_w = prev_W[var.name]
                    regular_terms.append(tf.nn.l2_loss(var - prev_w))
            self.loss = self.loss + self.lamba_regular * tf.reduce_mean(regular_terms)
        
        opt = tf.train.AdamOptimizer(self.lr)
        grads = opt.compute_gradients(self.loss, l1_var)
        apply_grads = opt.apply_gradients(grads)

        correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(self.y_,1))
        self.acc_train = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        
#         l1_var = [var for var in tf.trainable_variables()]
        l1_op_list = []
        with tf.control_dependencies([apply_grads]):  # exec apply_grads first
            for var in tf.trainable_variables():
                th_t = tf.fill(tf.shape(var), tf.convert_to_tensor(self.l1_thr))
                zero_t = tf.zeros(tf.shape(var))
#                 var_temp = var - (th_t * tf.sign(var))
                # [pseudo]:  if |var| < th_t: var = [0];  else: var = var_temp
                l1_op = var.assign(tf.where(tf.less(tf.abs(var), th_t), zero_t, var))
                l1_op_list.append(l1_op)
        
        with tf.control_dependencies(l1_op_list):
            self.train_model = tf.no_op()

    def train_task(self, task_id, batch_size, epochs, retraining=False, expansion=False):

        if task_id == 1:
            task_train_labels = tf.one_hot(indices=np.array(self.train_labels), depth=self.last_label_index+1)
        elif retraining == True or expansion == True:
            task_train_labels = tf.one_hot(indices=np.array(self.train_ex_labels), depth=self.last_label_index+1)
        else:
            task_train_labels = np.array(self.train_labels)
            task_train_labels = task_train_labels.reshape((task_train_labels.shape[0],1))
            task_train_labels = tf.convert_to_tensor(task_train_labels)

        dataset = tf.data.Dataset.from_tensor_slices((np.array(self.train), task_train_labels))
        dataset = dataset.shuffle(len(self.train_ex_labels)).repeat().batch(batch_size)
        iterator = dataset.make_one_shot_iterator()
        (x_data , y_data) = iterator.get_next()

        self.sess.run(tf.global_variables_initializer())
        task_train_labels = self.sess.run(task_train_labels)
        count = 0

#         for scope, ref in self.params.items():
#             if "l2" in scope:
#                 print(self.sess.run(ref))

        for i in range(epochs):

            for j in range(int(len(self.train)/batch_size)):
                x_batch , y_batch = self.sess.run([x_data,y_data])
                _, loss = self.sess.run([self.train_model, self.loss], feed_dict={self.x: x_batch, self.y_: y_batch})

            train_accuracy = self.acc_train.eval(session=self.sess, feed_dict={self.x: self.train, self.y_: task_train_labels})
            print("Epoch %d, training accuracy %g"%(i+1, train_accuracy))

            if train_accuracy == 1:
                count += 1

                if count > 9:
                    print("Best accuracy achieved! \n")
                    break
        
#         for scope, ref in self.params.items():
#             if "l2" in scope:
#                 print(self.sess.run(ref))
        
        return loss
    
    def predict(self, task_id, output_len=2):

        self.initialize_parameters(output_len)

        task_test_labels = tf.one_hot(indices=self.test_labels, depth=self.last_label_index+1)
        task_test_labels = self.sess.run(task_test_labels)
        
        #flattened first fc layer
        W_fc1 = self.get_variable(name="w", scope="l1")   # layer-1 outgoing weight matrix
        b_fc1 = self.get_variable(name="b", scope="l1")

        h_fc1 = tf.nn.relu(tf.matmul(self.x, W_fc1) + b_fc1)

        #second fc layer
        W_fc2 = self.get_variable(name="w", scope="l2")   # layer-2 outgoing weight matrix
        b_fc2 = self.get_variable(name="b", scope="l2")

        self.h_fc2 = tf.nn.relu(tf.matmul(h_fc1, W_fc2) + b_fc2)

        self.w_fc = self.get_variable(name="w", scope="l3")
        self.b_fc = self.get_variable(name="b", scope="l3")

        y_final = tf.matmul(self.h_fc2, self.w_fc) + self.b_fc
        y_final = tf.nn.softmax(y_final)
        
        self.sess.run(tf.global_variables_initializer())

        correct_prediction = tf.equal(tf.argmax(y_final,1), tf.argmax(self.y_,1))
        self.acc_test = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        test_accuracy = self.acc_test.eval(session=self.sess, feed_dict={self.x: self.test, self.y_: task_test_labels})
        return test_accuracy

# %%
if __name__ == "__main__":

    den = DEN()

    train_data, train_labels, test_data, test_labels, label_names = den.extract_data()
    np.random.shuffle(label_names)

# show image using cv
    # print(train_labels[512])
    # cv.imshow("", train_data[512])
    # cv.waitKey(0)

    tf.reset_default_graph()
    task_id = 0
    y_conv = None

    while den.last_label_index != (len(label_names) - 1):     # Loop for adding new tasks (lifelong learning)

        task_id += 1
        den.add_task(task_id, label_names)
        param_values = dict()
        selected = dict()
        print("-------------Training new task: %d--------------"%task_id)
        if task_id == 1:
            y_conv = den.build_model(task_id=task_id)
            den.optimization()
            _ = den.train_task(task_id=task_id, batch_size=den.batch_size, epochs=den.epochs)
            params = den.get_params()

            den.destroy_graph()
            den.restore_params(trainable=False, param_values=params)  # Freezes all learned weights making them non-trainable

            # ---------Performance-----------
            test_accuracy = den.predict(task_id=task_id, output_len=den.last_label_index+1)
            
        else:
            print("-----------Started Selective Retraining-------------")
            
            #------------------Selection-------------------
            print("---- Selecting nodes ----")
            y_conv = den.build_model(task_id=task_id, output_len=1)
            den.sess.run(tf.global_variables_initializer())
            params = den.get_params()
            den.optimization()
            
            _ = den.train_task(task_id=task_id, batch_size=den.batch_size, epochs=den.early_stop)
            params = den.get_params()
       
            [selected, selected_prev, all_indices] = den.perform_selection(task_id=task_id, values_dict=params)
            den.destroy_graph()

            #------------------Retraining-------------------
            print("\n---- Retraining selected nodes ----")
            y_conv = den.build_SR(task_id=task_id, selected=selected, output_len=den.last_label_index+1) 
            den.optimization(prev_W=selected_prev) 
            loss = den.train_task(task_id=task_id, batch_size=den.batch_size, epochs=den.epochs, retraining=True)

            print("Loss: %f"%loss)

            #--------------Performing Union----------------
            _vars = [(var.name, den.sess.run(var)) for var in tf.trainable_variables() if 'l' in var.name]

            for item in _vars:
                key, values = item
                selected[key] = values

            for i in reversed(range(1, den.den_layers+1)):
                if i == den.den_layers:
                    temp_weight = np.concatenate((params['l%d/w:0' % i], params['l%d/w_%d:0' % (i, task_id)]), axis=1)
                    temp_weight[np.ix_(all_indices['l%d' % i], list(range(den.last_label_index+1)))] = \
                        selected['l%d/w_%d:0' % (i, task_id)]
                    # Updating output matrix structure
                    params['l%d/w:0' % (i)] = temp_weight.tolist()
                    params['l%d/b:0' % (i)] = \
                        selected['l%d/b_%d:0' % (i, task_id)]

#                         params['l%d/w:0' % (i)] = np.concatenate([params['l%d/w:0' % (i)],params['l%d/w_%d:0' % (i,task_id)]], axis=1).tolist()
#                         params['l%d/b:0' % (i)] = np.concatenate([params['l%d/b:0' % (i)],params['l%d/b_%d:0' % (i,task_id)]], axis=0).tolist()
                else:
                    temp_weight = params['l%d/w:0' % i]
                    temp_biases = params['l%d/b:0' % i]
                    temp_weight[np.ix_(all_indices['l%d' % i], all_indices['l%d' % (i + 1)])] = \
                        selected['l%d/w:0' % i]
                    temp_biases[all_indices['l%d' % (i + 1)]] = \
                        selected['l%d/b:0' % i]
                    params['l%d/w:0' % i] = temp_weight
                    params['l%d/b:0' % i] = temp_biases

            den.destroy_graph()
            den.restore_params(trainable=False, param_values=params)  # Freezes all learned weights making them non-trainable

            # ---------Performance-----------
            test_accuracy = den.predict(task_id=task_id, output_len=den.last_label_index+1)
            
            if test_accuracy < 0.85:
                
                print("Overall accuracy: %g, lesser than threshold" %test_accuracy)
                print("-----------Started Dynamic Expansion------------")
                y_conv = den.build_model(task_id=task_id, expansion=True, output_len=den.last_label_index+1)
                den.optimization()
                _ = den.train_task(task_id=task_id, batch_size=den.batch_size, epochs=den.epochs, expansion=True)
                params = den.get_params()
                
                # deleting useless neurons added during expansion
                for i in reversed(range(1, den.den_layers)):
                    useless = []
                    prev_layer_weight = params['l%d/w:0'%i]
                    prev_layer_biases = params['l%d/b:0'%i]
                    
                    for j in range(prev_layer_weight.shape[1] - den.k_ex, prev_layer_weight.shape[1]):
                        if np.count_nonzero(prev_layer_weight[:, j]) == 0:
                            useless.append(j)
                    print(len(useless))

                    params['l%d/w:0'%i] = np.delete(prev_layer_weight, useless, axis = 1)
                    params['l%d/b:0'%i] = np.delete(prev_layer_biases, useless)
                    
                    next_layer_weight = params['l%d/w:0'%(i+1)]
                    params['l%d/w:0'%(i+1)] = np.delete(next_layer_weight, useless, axis = 0)
                    
                den.destroy_graph()
                den.restore_params(trainable=False, param_values=params)  # Freezes all learned weights making them non-trainable
                
                test_accuracy = den.predict(task_id=task_id, output_len=den.last_label_index+1)
        
        l2_n = den.get_variable(name="w", scope="l2")
        s = l2_n.get_shape().as_list()
        print(s)
        print("Final accuracy: %g \n" %test_accuracy)
# Out:
# ..........loading dataset from numpy files..........
#
#
#  Added new category: night_stand
#
#  Added new category: bench
# Train size: 373
# Test size: 106
# -------------Training new task: 1--------------
# Epoch 1, training accuracy 0.989276
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 0.994638
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Epoch 6, training accuracy 0.994638
# Epoch 7, training accuracy 1
# Epoch 8, training accuracy 1
# Epoch 9, training accuracy 1
# Epoch 10, training accuracy 0.997319
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 0.994638
# Epoch 13, training accuracy 0.997319
# Epoch 14, training accuracy 1
# Epoch 15, training accuracy 1
# Epoch 16, training accuracy 1
# Best accuracy achieved!
#
# [1024, 256]
# Final accuracy: 0.990566
#
#
#  Added new category: bed
#
#  Less samples; so taking them all
#
#  Less samples; so taking them all
# Train size: 888
# Test size: 206
# -------------Training new task: 2--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 237 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.971847
# Epoch 2, training accuracy 0.96509
# Epoch 3, training accuracy 0.98536
# Epoch 4, training accuracy 0.977477
# Epoch 5, training accuracy 0.986486
# Epoch 6, training accuracy 0.975225
# Epoch 7, training accuracy 0.988739
# Epoch 8, training accuracy 0.993243
# Epoch 9, training accuracy 0.97973
# Epoch 10, training accuracy 0.992117
# Epoch 11, training accuracy 0.981982
# Epoch 12, training accuracy 0.971847
# Epoch 13, training accuracy 0.989865
# Epoch 14, training accuracy 0.988739
# Epoch 15, training accuracy 0.988739
# Epoch 16, training accuracy 0.997748
# Epoch 17, training accuracy 0.994369
# Epoch 18, training accuracy 0.994369
# Epoch 19, training accuracy 0.993243
# Epoch 20, training accuracy 0.984234
# Epoch 21, training accuracy 0.974099
# Epoch 22, training accuracy 0.996622
# Epoch 23, training accuracy 0.98536
# Epoch 24, training accuracy 0.951577
# Epoch 25, training accuracy 0.972973
# Epoch 26, training accuracy 0.994369
# Epoch 27, training accuracy 0.993243
# Epoch 28, training accuracy 0.990991
# Epoch 29, training accuracy 0.988739
# Epoch 30, training accuracy 0.990991
# Epoch 31, training accuracy 0.994369
# Epoch 32, training accuracy 0.996622
# Epoch 33, training accuracy 0.990991
# Epoch 34, training accuracy 0.995495
# Epoch 35, training accuracy 0.997748
# Epoch 36, training accuracy 0.995495
# Epoch 37, training accuracy 0.988739
# Epoch 38, training accuracy 0.994369
# Epoch 39, training accuracy 0.995495
# Epoch 40, training accuracy 0.994369
# Epoch 41, training accuracy 0.993243
# Epoch 42, training accuracy 0.993243
# Epoch 43, training accuracy 0.980856
# Epoch 44, training accuracy 0.983108
# Epoch 45, training accuracy 0.996622
# Epoch 46, training accuracy 0.975225
# Epoch 47, training accuracy 0.957207
# Epoch 48, training accuracy 0.980856
# Epoch 49, training accuracy 0.994369
# Epoch 50, training accuracy 0.993243
# Loss: 0.383741
# [1024, 256]
# Final accuracy: 0.961165
#
#
#  Added new category: cone
# Train size: 332
# Test size: 226
# -------------Training new task: 3--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 238 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Epoch 6, training accuracy 1
# Epoch 7, training accuracy 1
# Epoch 8, training accuracy 1
# Epoch 9, training accuracy 1
# Epoch 10, training accuracy 1
# Best accuracy achieved!
#
# Loss: 0.405475
# [1024, 256]
# Final accuracy: 0.960177
#
#
#  Added new category: xbox
# Train size: 203
# Test size: 246
# -------------Training new task: 4--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 255 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.950739
# Epoch 2, training accuracy 0.995074
# Epoch 3, training accuracy 0.995074
# Epoch 4, training accuracy 0.995074
# Epoch 5, training accuracy 1
# Epoch 6, training accuracy 1
# Epoch 7, training accuracy 0.995074
# Epoch 8, training accuracy 1
# Epoch 9, training accuracy 1
# Epoch 10, training accuracy 1
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 0.995074
# Epoch 13, training accuracy 1
# Epoch 14, training accuracy 1
# Epoch 15, training accuracy 1
# Epoch 16, training accuracy 1
# Best accuracy achieved!
#
# Loss: 0.401064
# [1024, 256]
# Final accuracy: 0.934959
#
#
#  Added new category: lamp
# Train size: 244
# Test size: 266
# -------------Training new task: 5--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 254 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.979508
# Epoch 2, training accuracy 0.987705
# Epoch 3, training accuracy 0.979508
# Epoch 4, training accuracy 0.995902
# Epoch 5, training accuracy 0.991803
# Epoch 6, training accuracy 0.995902
# Epoch 7, training accuracy 0.995902
# Epoch 8, training accuracy 0.987705
# Epoch 9, training accuracy 0.995902
# Epoch 10, training accuracy 0.995902
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 1
# Epoch 13, training accuracy 0.991803
# Epoch 14, training accuracy 0.995902
# Epoch 15, training accuracy 1
# Epoch 16, training accuracy 0.995902
# Epoch 17, training accuracy 0.995902
# Epoch 18, training accuracy 0.995902
# Epoch 19, training accuracy 1
# Epoch 20, training accuracy 1
# Epoch 21, training accuracy 1
# Epoch 22, training accuracy 0.995902
# Epoch 23, training accuracy 1
# Epoch 24, training accuracy 1
# Epoch 25, training accuracy 0.995902
# Epoch 26, training accuracy 1
# Epoch 27, training accuracy 1
# Best accuracy achieved!
#
# Loss: 0.420750
# [1024, 256]
# Final accuracy: 0.93985
#
#
#  Added new category: desk
# Train size: 398
# Test size: 352
# -------------Training new task: 6--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 251 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.944724
# Epoch 2, training accuracy 0.972362
# Epoch 3, training accuracy 0.977387
# Epoch 4, training accuracy 0.98995
# Epoch 5, training accuracy 0.987437
# Epoch 6, training accuracy 0.977387
# Epoch 7, training accuracy 0.994975
# Epoch 8, training accuracy 0.994975
# Epoch 9, training accuracy 0.997487
# Epoch 10, training accuracy 0.974874
# Epoch 11, training accuracy 0.994975
# Epoch 12, training accuracy 0.994975
# Epoch 13, training accuracy 1
# Epoch 14, training accuracy 0.992462
# Epoch 15, training accuracy 0.992462
# Epoch 16, training accuracy 0.994975
# Epoch 17, training accuracy 1
# Epoch 18, training accuracy 0.992462
# Epoch 19, training accuracy 0.992462
# Epoch 20, training accuracy 0.992462
# Epoch 21, training accuracy 0.997487
# Epoch 22, training accuracy 0.994975
# Epoch 23, training accuracy 0.997487
# Epoch 24, training accuracy 0.994975
# Epoch 25, training accuracy 0.98995
# Epoch 26, training accuracy 0.994975
# Epoch 27, training accuracy 0.994975
# Epoch 28, training accuracy 1
# Epoch 29, training accuracy 1
# Epoch 30, training accuracy 0.98995
# Epoch 31, training accuracy 0.994975
# Epoch 32, training accuracy 1
# Epoch 33, training accuracy 1
# Epoch 34, training accuracy 0.994975
# Epoch 35, training accuracy 0.997487
# Epoch 36, training accuracy 0.977387
# Epoch 37, training accuracy 0.992462
# Epoch 38, training accuracy 0.994975
# Epoch 39, training accuracy 0.994975
# Epoch 40, training accuracy 0.969849
# Epoch 41, training accuracy 0.994975
# Epoch 42, training accuracy 0.994975
# Epoch 43, training accuracy 0.994975
# Epoch 44, training accuracy 0.98995
# Epoch 45, training accuracy 1
# Epoch 46, training accuracy 0.997487
# Epoch 47, training accuracy 1
# Epoch 48, training accuracy 1
# Epoch 49, training accuracy 0.997487
# Epoch 50, training accuracy 0.997487
# Loss: 0.483854
# [1024, 256]
# Final accuracy: 0.869318
#
#
#  Added new category: chair
#
#  Less samples; so taking them all
#
#  Less samples; so taking them all
# Train size: 1751
# Test size: 452
# -------------Training new task: 7--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 250 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.958881
# Epoch 2, training accuracy 0.960023
# Epoch 3, training accuracy 0.970874
# Epoch 4, training accuracy 0.980011
# Epoch 5, training accuracy 0.978869
# Epoch 6, training accuracy 0.96916
# Epoch 7, training accuracy 0.970874
# Epoch 8, training accuracy 0.972016
# Epoch 9, training accuracy 0.985151
# Epoch 10, training accuracy 0.973158
# Epoch 11, training accuracy 0.974872
# Epoch 12, training accuracy 0.980011
# Epoch 13, training accuracy 0.972016
# Epoch 14, training accuracy 0.960023
# Epoch 15, training accuracy 0.988578
# Epoch 16, training accuracy 0.982296
# Epoch 17, training accuracy 0.969732
# Epoch 18, training accuracy 0.985722
# Epoch 19, training accuracy 0.986294
# Epoch 20, training accuracy 0.968589
# Epoch 21, training accuracy 0.981154
# Epoch 22, training accuracy 0.968018
# Epoch 23, training accuracy 0.97944
# Epoch 24, training accuracy 0.966876
# Epoch 25, training accuracy 0.983438
# Epoch 26, training accuracy 0.973158
# Epoch 27, training accuracy 0.987436
# Epoch 28, training accuracy 0.967447
# Epoch 29, training accuracy 0.981154
# Epoch 30, training accuracy 0.978298
# Epoch 31, training accuracy 0.958881
# Epoch 32, training accuracy 0.964021
# Epoch 33, training accuracy 0.97944
# Epoch 34, training accuracy 0.977156
# Epoch 35, training accuracy 0.976014
# Epoch 36, training accuracy 0.975443
# Epoch 37, training accuracy 0.9743
# Epoch 38, training accuracy 0.986865
# Epoch 39, training accuracy 0.984009
# Epoch 40, training accuracy 0.980583
# Epoch 41, training accuracy 0.934894
# Epoch 42, training accuracy 0.982867
# Epoch 43, training accuracy 0.98458
# Epoch 44, training accuracy 0.988007
# Epoch 45, training accuracy 0.972016
# Epoch 46, training accuracy 0.969732
# Epoch 47, training accuracy 0.984009
# Epoch 48, training accuracy 0.978869
# Epoch 49, training accuracy 0.965734
# Epoch 50, training accuracy 0.978298
# Loss: 0.485143
# [1024, 256]
# Final accuracy: 0.909292
#
#
#  Added new category: bowl
# Train size: 224
# Test size: 472
# -------------Training new task: 8--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 255 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.991071
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Epoch 6, training accuracy 1
# Epoch 7, training accuracy 1
# Epoch 8, training accuracy 1
# Epoch 9, training accuracy 1
# Epoch 10, training accuracy 1
# Epoch 11, training accuracy 1
# Best accuracy achieved!
#
# Loss: 0.471899
# [1024, 256]
# Final accuracy: 0.917373
#
#
#  Added new category: car
# Train size: 386
# Test size: 572
# -------------Training new task: 9--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 252 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.971503
# Epoch 2, training accuracy 0.987047
# Epoch 3, training accuracy 0.984456
# Epoch 4, training accuracy 0.997409
# Epoch 5, training accuracy 0.997409
# Epoch 6, training accuracy 0.994819
# Epoch 7, training accuracy 0.997409
# Epoch 8, training accuracy 1
# Epoch 9, training accuracy 0.992228
# Epoch 10, training accuracy 0.997409
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 1
# Epoch 13, training accuracy 1
# Epoch 14, training accuracy 1
# Epoch 15, training accuracy 1
# Epoch 16, training accuracy 0.997409
# Epoch 17, training accuracy 0.997409
# Epoch 18, training accuracy 1
# Epoch 19, training accuracy 1
# Epoch 20, training accuracy 1
# Epoch 21, training accuracy 1
# Best accuracy achieved!
#
# Loss: 0.485746
# [1024, 256]
# Final accuracy: 0.902098
#
#
#  Added new category: tv_stand
# Train size: 527
# Test size: 672
# -------------Training new task: 10--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 256 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.888046
# Epoch 2, training accuracy 0.880455
# Epoch 3, training accuracy 0.937381
# Epoch 4, training accuracy 0.952562
# Epoch 5, training accuracy 0.952562
# Epoch 6, training accuracy 0.967742
# Epoch 7, training accuracy 0.962049
# Epoch 8, training accuracy 0.962049
# Epoch 9, training accuracy 0.988615
# Epoch 10, training accuracy 0.98482
# Epoch 11, training accuracy 0.99241
# Epoch 12, training accuracy 0.99241
# Epoch 13, training accuracy 0.982922
# Epoch 14, training accuracy 0.97723
# Epoch 15, training accuracy 0.988615
# Epoch 16, training accuracy 0.948767
# Epoch 17, training accuracy 0.988615
# Epoch 18, training accuracy 0.97723
# Epoch 19, training accuracy 0.99241
# Epoch 20, training accuracy 0.971537
# Epoch 21, training accuracy 0.986717
# Epoch 22, training accuracy 0.994307
# Epoch 23, training accuracy 0.98482
# Epoch 24, training accuracy 0.981025
# Epoch 25, training accuracy 0.994307
# Epoch 26, training accuracy 0.944972
# Epoch 27, training accuracy 1
# Epoch 28, training accuracy 0.996205
# Epoch 29, training accuracy 0.994307
# Epoch 30, training accuracy 0.99241
# Epoch 31, training accuracy 0.99241
# Epoch 32, training accuracy 0.996205
# Epoch 33, training accuracy 0.98482
# Epoch 34, training accuracy 0.97723
# Epoch 35, training accuracy 0.998102
# Epoch 36, training accuracy 0.996205
# Epoch 37, training accuracy 0.994307
# Epoch 38, training accuracy 0.986717
# Epoch 39, training accuracy 0.988615
# Epoch 40, training accuracy 0.990512
# Epoch 41, training accuracy 0.996205
# Epoch 42, training accuracy 0.971537
# Epoch 43, training accuracy 0.990512
# Epoch 44, training accuracy 0.990512
# Epoch 45, training accuracy 0.994307
# Epoch 46, training accuracy 0.973435
# Epoch 47, training accuracy 0.981025
# Epoch 48, training accuracy 0.996205
# Epoch 49, training accuracy 0.998102
# Epoch 50, training accuracy 0.986717
# Loss: 0.542489
# Overall accuracy: 0.822917, lesser than threshold
# -----------Started Dynamic Expansion------------
# Epoch 1, training accuracy 0.996205
# Epoch 2, training accuracy 0.996205
# Epoch 3, training accuracy 0.996205
# Epoch 4, training accuracy 0.998102
# Epoch 5, training accuracy 0.996205
# Epoch 6, training accuracy 0.996205
# Epoch 7, training accuracy 0.998102
# Epoch 8, training accuracy 0.998102
# Epoch 9, training accuracy 0.998102
# Epoch 10, training accuracy 0.998102
# Epoch 11, training accuracy 0.998102
# Epoch 12, training accuracy 0.998102
# Epoch 13, training accuracy 0.996205
# Epoch 14, training accuracy 0.998102
# Epoch 15, training accuracy 0.998102
# Epoch 16, training accuracy 0.998102
# Epoch 17, training accuracy 0.996205
# Epoch 18, training accuracy 0.998102
# Epoch 19, training accuracy 0.998102
# Epoch 20, training accuracy 0.998102
# Epoch 21, training accuracy 0.996205
# Epoch 22, training accuracy 0.998102
# Epoch 23, training accuracy 0.998102
# Epoch 24, training accuracy 0.998102
# Epoch 25, training accuracy 0.998102
# Epoch 26, training accuracy 0.998102
# Epoch 27, training accuracy 0.998102
# Epoch 28, training accuracy 0.998102
# Epoch 29, training accuracy 0.998102
# Epoch 30, training accuracy 0.998102
# Epoch 31, training accuracy 0.998102
# Epoch 32, training accuracy 0.998102
# Epoch 33, training accuracy 0.996205
# Epoch 34, training accuracy 0.998102
# Epoch 35, training accuracy 0.998102
# Epoch 36, training accuracy 0.998102
# Epoch 37, training accuracy 0.998102
# Epoch 38, training accuracy 0.998102
# Epoch 39, training accuracy 0.998102
# Epoch 40, training accuracy 0.996205
# Epoch 41, training accuracy 0.998102
# Epoch 42, training accuracy 0.996205
# Epoch 43, training accuracy 0.998102
# Epoch 44, training accuracy 0.998102
# Epoch 45, training accuracy 0.998102
# Epoch 46, training accuracy 0.998102
# Epoch 47, training accuracy 0.998102
# Epoch 48, training accuracy 0.996205
# Epoch 49, training accuracy 0.998102
# Epoch 50, training accuracy 0.996205
# 0
# 0
# [1029, 261]
# Final accuracy: 0.845238
#
#
#  Added new category: bottle
# Train size: 665
# Test size: 772
# -------------Training new task: 11--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 259 neurons
# Layer 2: Selecting 1029 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.960902
# Epoch 2, training accuracy 0.986466
# Epoch 3, training accuracy 0.983459
# Epoch 4, training accuracy 0.995489
# Epoch 5, training accuracy 0.989474
# Epoch 6, training accuracy 0.984962
# Epoch 7, training accuracy 0.984962
# Epoch 8, training accuracy 0.996992
# Epoch 9, training accuracy 0.993985
# Epoch 10, training accuracy 0.993985
# Epoch 11, training accuracy 0.993985
# Epoch 12, training accuracy 0.984962
# Epoch 13, training accuracy 0.992481
# Epoch 14, training accuracy 0.981955
# Epoch 15, training accuracy 0.990977
# Epoch 16, training accuracy 0.996992
# Epoch 17, training accuracy 0.995489
# Epoch 18, training accuracy 0.989474
# Epoch 19, training accuracy 0.998496
# Epoch 20, training accuracy 0.98797
# Epoch 21, training accuracy 0.995489
# Epoch 22, training accuracy 0.998496
# Epoch 23, training accuracy 0.969925
# Epoch 24, training accuracy 0.993985
# Epoch 25, training accuracy 0.995489
# Epoch 26, training accuracy 0.993985
# Epoch 27, training accuracy 0.993985
# Epoch 28, training accuracy 0.992481
# Epoch 29, training accuracy 0.977444
# Epoch 30, training accuracy 0.992481
# Epoch 31, training accuracy 0.993985
# Epoch 32, training accuracy 0.990977
# Epoch 33, training accuracy 0.998496
# Epoch 34, training accuracy 0.972932
# Epoch 35, training accuracy 0.992481
# Epoch 36, training accuracy 0.993985
# Epoch 37, training accuracy 0.989474
# Epoch 38, training accuracy 0.995489
# Epoch 39, training accuracy 0.998496
# Epoch 40, training accuracy 0.989474
# Epoch 41, training accuracy 0.993985
# Epoch 42, training accuracy 0.993985
# Epoch 43, training accuracy 0.996992
# Epoch 44, training accuracy 0.980451
# Epoch 45, training accuracy 0.98797
# Epoch 46, training accuracy 0.986466
# Epoch 47, training accuracy 0.98797
# Epoch 48, training accuracy 0.990977
# Epoch 49, training accuracy 1
# Epoch 50, training accuracy 0.989474
# Loss: 0.650301
# [1029, 261]
# Final accuracy: 0.882124
#
#
#  Added new category: stool
# Train size: 330
# Test size: 792
# -------------Training new task: 12--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 260 neurons
# Layer 2: Selecting 1029 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.827273
# Epoch 2, training accuracy 0.963636
# Epoch 3, training accuracy 0.978788
# Epoch 4, training accuracy 0.99697
# Epoch 5, training accuracy 0.99697
# Epoch 6, training accuracy 0.99697
# Epoch 7, training accuracy 0.99697
# Epoch 8, training accuracy 1
# Epoch 9, training accuracy 1
# Epoch 10, training accuracy 0.993939
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 0.99697
# Epoch 13, training accuracy 1
# Epoch 14, training accuracy 0.99697
# Epoch 15, training accuracy 0.981818
# Epoch 16, training accuracy 0.99697
# Epoch 17, training accuracy 1
# Epoch 18, training accuracy 1
# Epoch 19, training accuracy 0.987879
# Epoch 20, training accuracy 0.99697
# Epoch 21, training accuracy 1
# Epoch 22, training accuracy 1
# Epoch 23, training accuracy 0.990909
# Epoch 24, training accuracy 0.99697
# Epoch 25, training accuracy 1
# Epoch 26, training accuracy 1
# Best accuracy achieved!
#
# Loss: 0.585108
# [1029, 261]
# Final accuracy: 0.864899
#
#
#  Added new category: bookshelf
# Train size: 1144
# Test size: 892
# -------------Training new task: 13--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 260 neurons
# Layer 2: Selecting 1029 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.880245
# Epoch 2, training accuracy 0.918706
# Epoch 3, training accuracy 0.952797
# Epoch 4, training accuracy 0.945804
# Epoch 5, training accuracy 0.978147
# Epoch 6, training accuracy 0.971154
# Epoch 7, training accuracy 0.972028
# Epoch 8, training accuracy 0.963287
# Epoch 9, training accuracy 0.97028
# Epoch 10, training accuracy 0.95979
# Epoch 11, training accuracy 0.972902
# Epoch 12, training accuracy 0.912587
# Epoch 13, training accuracy 0.978147
# Epoch 14, training accuracy 0.963287
# Epoch 15, training accuracy 0.969406
# Epoch 16, training accuracy 0.97465
# Epoch 17, training accuracy 0.969406
# Epoch 18, training accuracy 0.964161
# Epoch 19, training accuracy 0.979895
# Epoch 20, training accuracy 0.984266
# Epoch 21, training accuracy 0.979021
# Epoch 22, training accuracy 0.975524
# Epoch 23, training accuracy 0.961538
# Epoch 24, training accuracy 0.978147
# Epoch 25, training accuracy 0.956294
# Epoch 26, training accuracy 0.953671
# Epoch 27, training accuracy 0.978147
# Epoch 28, training accuracy 0.971154
# Epoch 29, training accuracy 0.980769
# Epoch 30, training accuracy 0.971154
# Epoch 31, training accuracy 0.965909
# Epoch 32, training accuracy 0.973776
# Epoch 33, training accuracy 0.965035
# Epoch 34, training accuracy 0.980769
# Epoch 35, training accuracy 0.98514
# Epoch 36, training accuracy 0.969406
# Epoch 37, training accuracy 0.982517
# Epoch 38, training accuracy 0.979021
# Epoch 39, training accuracy 0.958916
# Epoch 40, training accuracy 0.977273
# Epoch 41, training accuracy 0.979021
# Epoch 42, training accuracy 0.969406
# Epoch 43, training accuracy 0.971154
# Epoch 44, training accuracy 0.950175
# Epoch 45, training accuracy 0.963287
# Epoch 46, training accuracy 0.964161
# Epoch 47, training accuracy 0.971154
# Epoch 48, training accuracy 0.964161
# Epoch 49, training accuracy 0.976399
# Epoch 50, training accuracy 0.976399
# Loss: 0.729106
# Overall accuracy: 0.825112, lesser than threshold
# -----------Started Dynamic Expansion------------
# Epoch 1, training accuracy 0.983392
# Epoch 2, training accuracy 0.986888
# Epoch 3, training accuracy 0.986888
# Epoch 4, training accuracy 0.986014
# Epoch 5, training accuracy 0.986014
# Epoch 6, training accuracy 0.988636
# Epoch 7, training accuracy 0.988636
# Epoch 8, training accuracy 0.988636
# Epoch 9, training accuracy 0.987762
# Epoch 10, training accuracy 0.987762
# Epoch 11, training accuracy 0.988636
# Epoch 12, training accuracy 0.986014
# Epoch 13, training accuracy 0.986888
# Epoch 14, training accuracy 0.986014
# Epoch 15, training accuracy 0.987762
# Epoch 16, training accuracy 0.986888
# Epoch 17, training accuracy 0.988636
# Epoch 18, training accuracy 0.986888
# Epoch 19, training accuracy 0.986888
# Epoch 20, training accuracy 0.987762
# Epoch 21, training accuracy 0.987762
# Epoch 22, training accuracy 0.986888
# Epoch 23, training accuracy 0.988636
# Epoch 24, training accuracy 0.986888
# Epoch 25, training accuracy 0.987762
# Epoch 26, training accuracy 0.988636
# Epoch 27, training accuracy 0.987762
# Epoch 28, training accuracy 0.987762
# Epoch 29, training accuracy 0.988636
# Epoch 30, training accuracy 0.98951
# Epoch 31, training accuracy 0.986888
# Epoch 32, training accuracy 0.986888
# Epoch 33, training accuracy 0.987762
# Epoch 34, training accuracy 0.987762
# Epoch 35, training accuracy 0.986888
# Epoch 36, training accuracy 0.98951
# Epoch 37, training accuracy 0.987762
# Epoch 38, training accuracy 0.98951
# Epoch 39, training accuracy 0.987762
# Epoch 40, training accuracy 0.986888
# Epoch 41, training accuracy 0.986014
# Epoch 42, training accuracy 0.987762
# Epoch 43, training accuracy 0.987762
# Epoch 44, training accuracy 0.986014
# Epoch 45, training accuracy 0.987762
# Epoch 46, training accuracy 0.987762
# Epoch 47, training accuracy 0.986888
# Epoch 48, training accuracy 0.986888
# Epoch 49, training accuracy 0.98951
# Epoch 50, training accuracy 0.986014
# 0
# 0
# [1034, 266]
# Final accuracy: 0.856502
#
#
#  Added new category: plant
# Train size: 520
# Test size: 992
# -------------Training new task: 14--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 266 neurons
# Layer 2: Selecting 1034 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.940385
# Epoch 2, training accuracy 0.988462
# Epoch 3, training accuracy 0.984615
# Epoch 4, training accuracy 0.996154
# Epoch 5, training accuracy 0.994231
# Epoch 6, training accuracy 0.994231
# Epoch 7, training accuracy 0.988462
# Epoch 8, training accuracy 0.996154
# Epoch 9, training accuracy 0.984615
# Epoch 10, training accuracy 0.992308
# Epoch 11, training accuracy 0.994231
# Epoch 12, training accuracy 0.988462
# Epoch 13, training accuracy 1
# Epoch 14, training accuracy 0.992308
# Epoch 15, training accuracy 0.990385
# Epoch 16, training accuracy 0.998077
# Epoch 17, training accuracy 0.992308
# Epoch 18, training accuracy 0.998077
# Epoch 19, training accuracy 0.988462
# Epoch 20, training accuracy 0.992308
# Epoch 21, training accuracy 0.994231
# Epoch 22, training accuracy 1
# Epoch 23, training accuracy 0.988462
# Epoch 24, training accuracy 0.984615
# Epoch 25, training accuracy 0.998077
# Epoch 26, training accuracy 0.992308
# Epoch 27, training accuracy 0.982692
# Epoch 28, training accuracy 0.980769
# Epoch 29, training accuracy 0.965385
# Epoch 30, training accuracy 0.994231
# Epoch 31, training accuracy 0.996154
# Epoch 32, training accuracy 0.988462
# Epoch 33, training accuracy 0.994231
# Epoch 34, training accuracy 0.998077
# Epoch 35, training accuracy 0.988462
# Epoch 36, training accuracy 0.994231
# Epoch 37, training accuracy 0.998077
# Epoch 38, training accuracy 0.998077
# Epoch 39, training accuracy 0.998077
# Epoch 40, training accuracy 0.992308
# Epoch 41, training accuracy 0.998077
# Epoch 42, training accuracy 0.976923
# Epoch 43, training accuracy 0.980769
# Epoch 44, training accuracy 0.994231
# Epoch 45, training accuracy 1
# Epoch 46, training accuracy 0.998077
# Epoch 47, training accuracy 1
# Epoch 48, training accuracy 1
# Epoch 49, training accuracy 0.982692
# Epoch 50, training accuracy 0.994231
# Loss: 0.612600
# [1034, 266]
# Final accuracy: 0.873992
#
#
#  Added new category: dresser
# Train size: 500
# Test size: 1078
# -------------Training new task: 15--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 265 neurons
# Layer 2: Selecting 1034 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.882
# Epoch 2, training accuracy 0.884
# Epoch 3, training accuracy 0.95
# Epoch 4, training accuracy 0.954
# Epoch 5, training accuracy 0.96
# Epoch 6, training accuracy 0.976
# Epoch 7, training accuracy 0.964
# Epoch 8, training accuracy 0.954
# Epoch 9, training accuracy 0.984
# Epoch 10, training accuracy 0.972
# Epoch 11, training accuracy 0.992
# Epoch 12, training accuracy 0.978
# Epoch 13, training accuracy 0.968
# Epoch 14, training accuracy 0.99
# Epoch 15, training accuracy 0.984
# Epoch 16, training accuracy 0.99
# Epoch 17, training accuracy 0.99
# Epoch 18, training accuracy 0.99
# Epoch 19, training accuracy 0.968
# Epoch 20, training accuracy 0.98
# Epoch 21, training accuracy 0.988
# Epoch 22, training accuracy 0.992
# Epoch 23, training accuracy 0.994
# Epoch 24, training accuracy 0.992
# Epoch 25, training accuracy 0.972
# Epoch 26, training accuracy 0.958
# Epoch 27, training accuracy 0.992
# Epoch 28, training accuracy 0.998
# Epoch 29, training accuracy 0.978
# Epoch 30, training accuracy 0.994
# Epoch 31, training accuracy 0.994
# Epoch 32, training accuracy 0.982
# Epoch 33, training accuracy 0.996
# Epoch 34, training accuracy 0.98
# Epoch 35, training accuracy 0.982
# Epoch 36, training accuracy 0.972
# Epoch 37, training accuracy 0.984
# Epoch 38, training accuracy 0.986
# Epoch 39, training accuracy 0.992
# Epoch 40, training accuracy 0.984
# Epoch 41, training accuracy 0.988
# Epoch 42, training accuracy 0.996
# Epoch 43, training accuracy 0.99
# Epoch 44, training accuracy 0.994
# Epoch 45, training accuracy 0.986
# Epoch 46, training accuracy 0.948
# Epoch 47, training accuracy 0.986
# Epoch 48, training accuracy 0.998
# Epoch 49, training accuracy 0.988
# Epoch 50, training accuracy 0.97
# Loss: 0.697464
# Overall accuracy: 0.812616, lesser than threshold
# -----------Started Dynamic Expansion------------
# Epoch 1, training accuracy 0.988
# Epoch 2, training accuracy 0.99
# Epoch 3, training accuracy 0.99
# Epoch 4, training accuracy 0.99
# Epoch 5, training accuracy 0.994
# Epoch 6, training accuracy 0.994
# Epoch 7, training accuracy 0.996
# Epoch 8, training accuracy 0.996
# Epoch 9, training accuracy 0.996
# Epoch 10, training accuracy 0.996
# Epoch 11, training accuracy 0.996
# Epoch 12, training accuracy 0.996
# Epoch 13, training accuracy 0.998
# Epoch 14, training accuracy 0.998
# Epoch 15, training accuracy 0.998
# Epoch 16, training accuracy 0.998
# Epoch 17, training accuracy 0.998
# Epoch 18, training accuracy 0.998
# Epoch 19, training accuracy 0.998
# Epoch 20, training accuracy 1
# Epoch 21, training accuracy 0.998
# Epoch 22, training accuracy 1
# Epoch 23, training accuracy 1
# Epoch 24, training accuracy 1
# Epoch 25, training accuracy 1
# Epoch 26, training accuracy 1
# Epoch 27, training accuracy 1
# Epoch 28, training accuracy 1
# Epoch 29, training accuracy 1
# Epoch 30, training accuracy 1
# Best accuracy achieved!
#
# 0
# 0
# [1039, 271]
# Final accuracy: 0.83859
#
#
#  Added new category: stairs
# Train size: 444
# Test size: 1098
# -------------Training new task: 16--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 266 neurons
# Layer 2: Selecting 1039 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.914414
# Epoch 2, training accuracy 0.972973
# Epoch 3, training accuracy 0.981982
# Epoch 4, training accuracy 0.977477
# Epoch 5, training accuracy 0.988739
# Epoch 6, training accuracy 0.995495
# Epoch 7, training accuracy 0.997748
# Epoch 8, training accuracy 0.997748
# Epoch 9, training accuracy 0.993243
# Epoch 10, training accuracy 0.997748
# Epoch 11, training accuracy 0.997748
# Epoch 12, training accuracy 0.990991
# Epoch 13, training accuracy 0.990991
# Epoch 14, training accuracy 0.995495
# Epoch 15, training accuracy 0.990991
# Epoch 16, training accuracy 0.995495
# Epoch 17, training accuracy 1
# Epoch 18, training accuracy 1
# Epoch 19, training accuracy 0.995495
# Epoch 20, training accuracy 0.995495
# Epoch 21, training accuracy 0.997748
# Epoch 22, training accuracy 0.995495
# Epoch 23, training accuracy 0.984234
# Epoch 24, training accuracy 0.993243
# Epoch 25, training accuracy 0.995495
# Epoch 26, training accuracy 0.993243
# Epoch 27, training accuracy 1
# Epoch 28, training accuracy 0.995495
# Epoch 29, training accuracy 0.997748
# Epoch 30, training accuracy 0.993243
# Epoch 31, training accuracy 0.986486
# Epoch 32, training accuracy 0.997748
# Epoch 33, training accuracy 1
# Epoch 34, training accuracy 0.995495
# Epoch 35, training accuracy 1
# Epoch 36, training accuracy 1
# Epoch 37, training accuracy 1
# Epoch 38, training accuracy 0.997748
# Epoch 39, training accuracy 0.963964
# Epoch 40, training accuracy 0.972973
# Epoch 41, training accuracy 0.988739
# Epoch 42, training accuracy 0.988739
# Epoch 43, training accuracy 0.997748
# Epoch 44, training accuracy 0.995495
# Epoch 45, training accuracy 0.997748
# Epoch 46, training accuracy 0.993243
# Epoch 47, training accuracy 0.997748
# Epoch 48, training accuracy 1
# Epoch 49, training accuracy 0.995495
# Epoch 50, training accuracy 0.993243
# Loss: 0.671989
# Overall accuracy: 0.834244, lesser than threshold
# -----------Started Dynamic Expansion------------
# Epoch 1, training accuracy 0.993243
# Epoch 2, training accuracy 0.993243
# Epoch 3, training accuracy 0.993243
# Epoch 4, training accuracy 0.993243
# Epoch 5, training accuracy 0.993243
# Epoch 6, training accuracy 0.993243
# Epoch 7, training accuracy 0.993243
# Epoch 8, training accuracy 0.993243
# Epoch 9, training accuracy 0.993243
# Epoch 10, training accuracy 0.993243
# Epoch 11, training accuracy 0.993243
# Epoch 12, training accuracy 0.993243
# Epoch 13, training accuracy 0.993243
# Epoch 14, training accuracy 0.993243
# Epoch 15, training accuracy 0.993243
# Epoch 16, training accuracy 0.993243
# Epoch 17, training accuracy 0.993243
# Epoch 18, training accuracy 0.993243
# Epoch 19, training accuracy 0.993243
# Epoch 20, training accuracy 0.993243
# Epoch 21, training accuracy 0.993243
# Epoch 22, training accuracy 0.993243
# Epoch 23, training accuracy 0.993243
# Epoch 24, training accuracy 0.993243
# Epoch 25, training accuracy 0.993243
# Epoch 26, training accuracy 0.993243
# Epoch 27, training accuracy 0.993243
# Epoch 28, training accuracy 0.993243
# Epoch 29, training accuracy 0.993243
# Epoch 30, training accuracy 0.993243
# Epoch 31, training accuracy 0.993243
# Epoch 32, training accuracy 0.993243
# Epoch 33, training accuracy 0.993243
# Epoch 34, training accuracy 0.993243
# Epoch 35, training accuracy 0.993243
# Epoch 36, training accuracy 0.993243
# Epoch 37, training accuracy 0.993243
# Epoch 38, training accuracy 0.993243
# Epoch 39, training accuracy 0.993243
# Epoch 40, training accuracy 0.993243
# Epoch 41, training accuracy 0.993243
# Epoch 42, training accuracy 0.993243
# Epoch 43, training accuracy 0.993243
# Epoch 44, training accuracy 0.993243
# Epoch 45, training accuracy 0.993243
# Epoch 46, training accuracy 0.993243
# Epoch 47, training accuracy 0.993243
# Epoch 48, training accuracy 0.993243
# Epoch 49, training accuracy 0.993243
# Epoch 50, training accuracy 0.993243
# 0
# 0
# [1044, 276]
# Final accuracy: 0.834244
#
#
#  Added new category: keyboard
# Train size: 485
# Test size: 1118
# -------------Training new task: 17--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 275 neurons
# Layer 2: Selecting 1044 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.936082
# Epoch 2, training accuracy 0.983505
# Epoch 3, training accuracy 0.991753
# Epoch 4, training accuracy 0.991753
# Epoch 5, training accuracy 0.989691
# Epoch 6, training accuracy 0.969072
# Epoch 7, training accuracy 0.997938
# Epoch 8, training accuracy 0.993814
# Epoch 9, training accuracy 0.997938
# Epoch 10, training accuracy 0.995876
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 1
# Epoch 13, training accuracy 0.981443
# Epoch 14, training accuracy 0.989691
# Epoch 15, training accuracy 0.987629
# Epoch 16, training accuracy 0.993814
# Epoch 17, training accuracy 0.997938
# Epoch 18, training accuracy 1
# Epoch 19, training accuracy 0.991753
# Epoch 20, training accuracy 1
# Epoch 21, training accuracy 0.991753
# Epoch 22, training accuracy 0.993814
# Epoch 23, training accuracy 0.983505
# Epoch 24, training accuracy 0.993814
# Epoch 25, training accuracy 1
# Epoch 26, training accuracy 0.997938
# Epoch 27, training accuracy 0.987629
# Epoch 28, training accuracy 0.987629
# Epoch 29, training accuracy 1
# Epoch 30, training accuracy 0.995876
# Epoch 31, training accuracy 0.997938
# Epoch 32, training accuracy 0.946392
# Epoch 33, training accuracy 0.995876
# Epoch 34, training accuracy 0.995876
# Epoch 35, training accuracy 0.997938
# Epoch 36, training accuracy 0.997938
# Epoch 37, training accuracy 0.995876
# Epoch 38, training accuracy 0.993814
# Epoch 39, training accuracy 0.995876
# Epoch 40, training accuracy 1
# Epoch 41, training accuracy 0.995876
# Epoch 42, training accuracy 0.995876
# Epoch 43, training accuracy 0.987629
# Epoch 44, training accuracy 0.995876
# Epoch 45, training accuracy 0.981443
# Epoch 46, training accuracy 0.993814
# Epoch 47, training accuracy 0.983505
# Epoch 48, training accuracy 0.997938
# Epoch 49, training accuracy 0.991753
# Epoch 50, training accuracy 0.981443
# Loss: 0.768051
# Overall accuracy: 0.800537, lesser than threshold
# -----------Started Dynamic Expansion------------
# Epoch 1, training accuracy 0.985567
# Epoch 2, training accuracy 0.987629
# Epoch 3, training accuracy 0.987629
# Epoch 4, training accuracy 0.989691
# Epoch 5, training accuracy 0.991753
# Epoch 6, training accuracy 0.991753
# Epoch 7, training accuracy 0.991753
# Epoch 8, training accuracy 0.991753
# Epoch 9, training accuracy 0.993814
# Epoch 10, training accuracy 0.993814
# Epoch 11, training accuracy 0.993814
# Epoch 12, training accuracy 0.993814
# Epoch 13, training accuracy 0.997938
# Epoch 14, training accuracy 1
# Epoch 15, training accuracy 1
# Epoch 16, training accuracy 1
# Epoch 17, training accuracy 1
# Epoch 18, training accuracy 1
# Epoch 19, training accuracy 1
# Epoch 20, training accuracy 1
# Epoch 21, training accuracy 1
# Epoch 22, training accuracy 1
# Epoch 23, training accuracy 1
# Best accuracy achieved!
#
# 0
# 0
# [1049, 281]
# Final accuracy: 0.855098
#
#
#  Added new category: tent
# Train size: 523
# Test size: 1138
# -------------Training new task: 18--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 274 neurons
# Layer 2: Selecting 1049 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.889101
# Epoch 2, training accuracy 0.910134
# Epoch 3, training accuracy 0.946463
# Epoch 4, training accuracy 0.961759
# Epoch 5, training accuracy 0.982792
# Epoch 6, training accuracy 0.973231
# Epoch 7, training accuracy 0.98088
# Epoch 8, training accuracy 0.99044
# Epoch 9, training accuracy 0.984704
# Epoch 10, training accuracy 0.99044
# Epoch 11, training accuracy 0.99044
# Epoch 12, training accuracy 0.975143
# Epoch 13, training accuracy 0.984704
# Epoch 14, training accuracy 0.986616
# Epoch 15, training accuracy 0.973231
# Epoch 16, training accuracy 0.994264
# Epoch 17, training accuracy 0.986616
# Epoch 18, training accuracy 0.98088
# Epoch 19, training accuracy 0.973231
# Epoch 20, training accuracy 0.99044
# Epoch 21, training accuracy 0.98088
# Epoch 22, training accuracy 0.978967
# Epoch 23, training accuracy 0.986616
# Epoch 24, training accuracy 0.986616
# Epoch 25, training accuracy 0.986616
# Epoch 26, training accuracy 0.986616
# Epoch 27, training accuracy 0.99044
# Epoch 28, training accuracy 0.996176
# Epoch 29, training accuracy 0.973231
# Epoch 30, training accuracy 0.950287
# Epoch 31, training accuracy 0.986616
# Epoch 32, training accuracy 0.988528
# Epoch 33, training accuracy 0.984704
# Epoch 34, training accuracy 0.944551
# Epoch 35, training accuracy 0.978967
# Epoch 36, training accuracy 0.988528
# Epoch 37, training accuracy 0.986616
# Epoch 38, training accuracy 0.99044
# Epoch 39, training accuracy 0.988528
# Epoch 40, training accuracy 0.99044
# Epoch 41, training accuracy 0.982792
# Epoch 42, training accuracy 0.984704
# Epoch 43, training accuracy 0.986616
# Epoch 44, training accuracy 0.986616
# Epoch 45, training accuracy 0.98088
# Epoch 46, training accuracy 0.946463
# Epoch 47, training accuracy 0.984704
# Epoch 48, training accuracy 0.996176
# Epoch 49, training accuracy 0.992352
# Epoch 50, training accuracy 0.994264
# Loss: 0.734556
# Overall accuracy: 0.846221, lesser than threshold
# -----------Started Dynamic Expansion------------
# Epoch 1, training accuracy 0.996176
# Epoch 2, training accuracy 0.998088
# Epoch 3, training accuracy 0.998088
# Epoch 4, training accuracy 0.998088
# Epoch 5, training accuracy 0.998088
# Epoch 6, training accuracy 0.996176
# Epoch 7, training accuracy 0.998088
# Epoch 8, training accuracy 0.996176
# Epoch 9, training accuracy 0.996176
# Epoch 10, training accuracy 0.996176
# Epoch 11, training accuracy 0.996176
# Epoch 12, training accuracy 0.996176
# Epoch 13, training accuracy 0.996176
# Epoch 14, training accuracy 0.996176
# Epoch 15, training accuracy 0.996176
# Epoch 16, training accuracy 0.996176
# Epoch 17, training accuracy 0.998088
# Epoch 18, training accuracy 0.996176
# Epoch 19, training accuracy 0.996176
# Epoch 20, training accuracy 0.996176
# Epoch 21, training accuracy 0.996176
# Epoch 22, training accuracy 0.996176
# Epoch 23, training accuracy 0.996176
# Epoch 24, training accuracy 0.996176
# Epoch 25, training accuracy 0.996176
# Epoch 26, training accuracy 0.996176
# Epoch 27, training accuracy 0.996176
# Epoch 28, training accuracy 0.996176
# Epoch 29, training accuracy 0.996176
# Epoch 30, training accuracy 0.998088
# Epoch 31, training accuracy 0.996176
# Epoch 32, training accuracy 0.996176
# Epoch 33, training accuracy 0.996176
# Epoch 34, training accuracy 0.996176
# Epoch 35, training accuracy 0.996176
# Epoch 36, training accuracy 0.998088
# Epoch 37, training accuracy 0.996176
# Epoch 38, training accuracy 0.998088
# Epoch 39, training accuracy 0.996176
# Epoch 40, training accuracy 0.996176
# Epoch 41, training accuracy 0.998088
# Epoch 42, training accuracy 0.996176
# Epoch 43, training accuracy 0.996176
# Epoch 44, training accuracy 0.998088
# Epoch 45, training accuracy 0.996176
# Epoch 46, training accuracy 0.996176
# Epoch 47, training accuracy 0.998088
# Epoch 48, training accuracy 0.996176
# Epoch 49, training accuracy 0.998088
# Epoch 50, training accuracy 0.996176
# 0
# 0
# [1054, 286]
# Final accuracy: 0.853251
#
#
#  Added new category: curtain
# Train size: 518
# Test size: 1158
# -------------Training new task: 19--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 285 neurons
# Layer 2: Selecting 1054 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.901544
# Epoch 2, training accuracy 0.96139
# Epoch 3, training accuracy 0.969112
# Epoch 4, training accuracy 0.988417
# Epoch 5, training accuracy 0.992278
# Epoch 6, training accuracy 0.992278
# Epoch 7, training accuracy 0.994209
# Epoch 8, training accuracy 0.986486
# Epoch 9, training accuracy 0.994209
# Epoch 10, training accuracy 0.969112
# Epoch 11, training accuracy 0.990348
# Epoch 12, training accuracy 0.996139
# Epoch 13, training accuracy 0.99807
# Epoch 14, training accuracy 0.99807
# Epoch 15, training accuracy 0.996139
# Epoch 16, training accuracy 0.992278
# Epoch 17, training accuracy 0.992278
# Epoch 18, training accuracy 0.988417
# Epoch 19, training accuracy 0.994209
# Epoch 20, training accuracy 0.996139
# Epoch 21, training accuracy 0.996139
# Epoch 22, training accuracy 0.978764
# Epoch 23, training accuracy 0.992278
# Epoch 24, training accuracy 0.990348
# Epoch 25, training accuracy 0.992278
# Epoch 26, training accuracy 0.992278
# Epoch 27, training accuracy 0.992278
# Epoch 28, training accuracy 0.992278
# Epoch 29, training accuracy 0.982625
# Epoch 30, training accuracy 0.984556
# Epoch 31, training accuracy 0.992278
# Epoch 32, training accuracy 0.990348
# Epoch 33, training accuracy 0.99807
# Epoch 34, training accuracy 0.994209
# Epoch 35, training accuracy 0.994209
# Epoch 36, training accuracy 0.996139
# Epoch 37, training accuracy 0.980695
# Epoch 38, training accuracy 0.982625
# Epoch 39, training accuracy 0.996139
# Epoch 40, training accuracy 0.992278
# Epoch 41, training accuracy 0.990348
# Epoch 42, training accuracy 0.996139
# Epoch 43, training accuracy 0.980695
# Epoch 44, training accuracy 0.988417
# Epoch 45, training accuracy 0.99807
# Epoch 46, training accuracy 0.996139
# Epoch 47, training accuracy 0.994209
# Epoch 48, training accuracy 0.982625
# Epoch 49, training accuracy 0.980695
# Epoch 50, training accuracy 0.994209
# Loss: 0.682964
# [1054, 286]
# Final accuracy: 0.864421
#
#
#  Added new category: glass_box
# Train size: 571
# Test size: 1258
# -------------Training new task: 20--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 283 neurons
# Layer 2: Selecting 1054 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.886165
# Epoch 2, training accuracy 0.93345
# Epoch 3, training accuracy 0.957968
# Epoch 4, training accuracy 0.964974
# Epoch 5, training accuracy 0.971979
# Epoch 6, training accuracy 0.971979
# Epoch 7, training accuracy 0.980736
# Epoch 8, training accuracy 0.97373
# Epoch 9, training accuracy 0.984238
# Epoch 10, training accuracy 0.987741
# Epoch 11, training accuracy 0.989492
# Epoch 12, training accuracy 0.982487
# Epoch 13, training accuracy 0.98599
# Epoch 14, training accuracy 0.964974
# Epoch 15, training accuracy 0.984238
# Epoch 16, training accuracy 0.977233
# Epoch 17, training accuracy 0.987741
# Epoch 18, training accuracy 0.984238
# Epoch 19, training accuracy 0.98599
# Epoch 20, training accuracy 0.989492
# Epoch 21, training accuracy 0.964974
# Epoch 22, training accuracy 0.991243
# Epoch 23, training accuracy 0.996497
# Epoch 24, training accuracy 0.970228
# Epoch 25, training accuracy 0.994746
# Epoch 26, training accuracy 0.989492
# Epoch 27, training accuracy 0.963222
# Epoch 28, training accuracy 0.987741
# Epoch 29, training accuracy 0.975482
# Epoch 30, training accuracy 0.950963
# Epoch 31, training accuracy 0.968476
# Epoch 32, training accuracy 0.996497
# Epoch 33, training accuracy 0.998249
# Epoch 34, training accuracy 0.980736
# Epoch 35, training accuracy 0.98599
# Epoch 36, training accuracy 0.984238
# Epoch 37, training accuracy 0.98599
# Epoch 38, training accuracy 0.984238
# Epoch 39, training accuracy 0.98599
# Epoch 40, training accuracy 0.971979
# Epoch 41, training accuracy 0.97373
# Epoch 42, training accuracy 0.971979
# Epoch 43, training accuracy 0.994746
# Epoch 44, training accuracy 0.968476
# Epoch 45, training accuracy 0.987741
# Epoch 46, training accuracy 0.970228
# Epoch 47, training accuracy 0.98599
# Epoch 48, training accuracy 0.98599
# Epoch 49, training accuracy 0.991243
# Epoch 50, training accuracy 0.989492
# Loss: 0.702220
# [1054, 286]
# Final accuracy: 0.850556
#
#
#  Added new category: flower_pot
# Train size: 569
# Test size: 1278
# -------------Training new task: 21--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 285 neurons
# Layer 2: Selecting 1054 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.910369
# Epoch 2, training accuracy 0.910369
# Epoch 3, training accuracy 0.966608
# Epoch 4, training accuracy 0.97188
# Epoch 5, training accuracy 0.97891
# Epoch 6, training accuracy 0.982425
# Epoch 7, training accuracy 0.964851
# Epoch 8, training accuracy 0.950791
# Epoch 9, training accuracy 0.97188
# ...
# Epoch 19, training accuracy 0.97012
# Epoch 20, training accuracy 0.959163
# Epoch 21, training accuracy 0.965139
# Epoch 22, training accuracy 0.958167
# Epoch 23, training accuracy 0.946215
# Epoch 24, training accuracy 0.957171
# Epoch 25, training accuracy 0.954183
# Epoch 26, training accuracy 0.964143
# Epoch 27, training accuracy 0.951195
# Epoch 28, training accuracy 0.961155
# Epoch 29, training accuracy 0.932271
# Epoch 30, training accuracy 0.959163
# Epoch 31, training accuracy 0.943227
# Epoch 32, training accuracy 0.97012
# Epoch 33, training accuracy 0.953187
# Epoch 34, training accuracy 0.964143
# Epoch 35, training accuracy 0.977092
# Epoch 36, training accuracy 0.971116
# Epoch 37, training accuracy 0.972112
# Epoch 38, training accuracy 0.965139
# Epoch 39, training accuracy 0.967131
# Epoch 40, training accuracy 0.966135
# Epoch 41, training accuracy 0.967131
# Epoch 42, training accuracy 0.973108
# Epoch 43, training accuracy 0.943227
# Epoch 44, training accuracy 0.972112
# Epoch 45, training accuracy 0.97012
# Epoch 46, training accuracy 0.959163
# Epoch 47, training accuracy 0.961155
# Epoch 48, training accuracy 0.969123
# Epoch 49, training accuracy 0.966135
# Epoch 50, training accuracy 0.950199
# Loss: 1.027570
# Overall accuracy: 0.738879, lesser than threshold
# -----------Started Dynamic Expansion------------
# Epoch 1, training accuracy 0.958167
# Epoch 2, training accuracy 0.964143
# Epoch 3, training accuracy 0.972112
# Epoch 4, training accuracy 0.983068
# Epoch 5, training accuracy 0.983068
# Epoch 6, training accuracy 0.98506
# Epoch 7, training accuracy 0.986056
# Epoch 8, training accuracy 0.987052
# Epoch 9, training accuracy 0.988048
# Epoch 10, training accuracy 0.99004
# Epoch 11, training accuracy 0.99004
# Epoch 12, training accuracy 0.99004
# Epoch 13, training accuracy 0.991036
# Epoch 14, training accuracy 0.991036
# Epoch 15, training accuracy 0.989044
# Epoch 16, training accuracy 0.99004
# Epoch 17, training accuracy 0.99004
# Epoch 18, training accuracy 0.99004
# Epoch 19, training accuracy 0.99004
# Epoch 20, training accuracy 0.99004
# Epoch 21, training accuracy 0.992032
# Epoch 22, training accuracy 0.99004
# Epoch 23, training accuracy 0.989044
# Epoch 24, training accuracy 0.99004
# Epoch 25, training accuracy 0.993028
# Epoch 26, training accuracy 0.99004
# Epoch 27, training accuracy 0.99004
# Epoch 28, training accuracy 0.991036
# Epoch 29, training accuracy 0.991036
# Epoch 30, training accuracy 0.99004
# Epoch 31, training accuracy 0.99004
# Epoch 32, training accuracy 0.991036
# Epoch 33, training accuracy 0.992032
# Epoch 34, training accuracy 0.992032
# Epoch 35, training accuracy 0.991036
# Epoch 36, training accuracy 0.992032
# Epoch 37, training accuracy 0.992032
# Epoch 38, training accuracy 0.99004
# Epoch 39, training accuracy 0.991036
# Epoch 40, training accuracy 0.991036
# Epoch 41, training accuracy 0.992032
# Epoch 42, training accuracy 0.991036
# Epoch 43, training accuracy 0.991036
# Epoch 44, training accuracy 0.992032
# Epoch 45, training accuracy 0.991036
# Epoch 46, training accuracy 0.992032
# Epoch 47, training accuracy 0.992032
# Epoch 48, training accuracy 0.991036
# Epoch 49, training accuracy 0.992032
# Epoch 50, training accuracy 0.992032
# 0
# 0
# [1134, 366]
# Final accuracy: 0.799822
#
#
#  Added new category: wardrobe
# Train size: 827
# Test size: 2268
# -------------Training new task: 37--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 362 neurons
# Layer 2: Selecting 1134 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.857316
# Epoch 2, training accuracy 0.899637
# Epoch 3, training accuracy 0.933495
# Epoch 4, training accuracy 0.916566
# Epoch 5, training accuracy 0.937122
# Epoch 6, training accuracy 0.946796
# Epoch 7, training accuracy 0.952842
# Epoch 8, training accuracy 0.948005
# Epoch 9, training accuracy 0.944377
# Epoch 10, training accuracy 0.909311
# Epoch 11, training accuracy 0.944377
# Epoch 12, training accuracy 0.970979
# Epoch 13, training accuracy 0.958888
# Epoch 14, training accuracy 0.962515
# Epoch 15, training accuracy 0.954051
# Epoch 16, training accuracy 0.951632
# Epoch 17, training accuracy 0.970979
# Epoch 18, training accuracy 0.937122
# Epoch 19, training accuracy 0.935913
# Epoch 20, training accuracy 0.960097
# Epoch 21, training accuracy 0.943168
# Epoch 22, training accuracy 0.946796
# Epoch 23, training accuracy 0.946796
# Epoch 24, training accuracy 0.932285
# Epoch 25, training accuracy 0.957678
# Epoch 26, training accuracy 0.943168
# Epoch 27, training accuracy 0.95526
# Epoch 28, training accuracy 0.963724
# Epoch 29, training accuracy 0.902056
# Epoch 30, training accuracy 0.943168
# Epoch 31, training accuracy 0.958888
# Epoch 32, training accuracy 0.944377
# Epoch 33, training accuracy 0.977025
# Epoch 34, training accuracy 0.94075
# Epoch 35, training accuracy 0.962515
# Epoch 36, training accuracy 0.958888
# Epoch 37, training accuracy 0.956469
# Epoch 38, training accuracy 0.929867
# Epoch 39, training accuracy 0.956469
# Epoch 40, training accuracy 0.938331
# Epoch 41, training accuracy 0.958888
# Epoch 42, training accuracy 0.951632
# Epoch 43, training accuracy 0.972189
# Epoch 44, training accuracy 0.952842
# Epoch 45, training accuracy 0.961306
# Epoch 46, training accuracy 0.960097
# Epoch 47, training accuracy 0.961306
# Epoch 48, training accuracy 0.968561
# Epoch 49, training accuracy 0.956469
# Epoch 50, training accuracy 0.951632
# Loss: 1.246959
# Overall accuracy: 0.767637, lesser than threshold
# -----------Started Dynamic Expansion------------
# Epoch 1, training accuracy 0.956469
# Epoch 2, training accuracy 0.957678
# Epoch 3, training accuracy 0.958888
# Epoch 4, training accuracy 0.968561
# Epoch 5, training accuracy 0.973398
# Epoch 6, training accuracy 0.977025
# Epoch 7, training accuracy 0.981862
# Epoch 8, training accuracy 0.983071
# Epoch 9, training accuracy 0.984281
# Epoch 10, training accuracy 0.98549
# Epoch 11, training accuracy 0.986699
# Epoch 12, training accuracy 0.98549
# Epoch 13, training accuracy 0.98549
# Epoch 14, training accuracy 0.98549
# Epoch 15, training accuracy 0.98549
# Epoch 16, training accuracy 0.98549
# Epoch 17, training accuracy 0.98549
# Epoch 18, training accuracy 0.98549
# Epoch 19, training accuracy 0.98549
# Epoch 20, training accuracy 0.986699
# Epoch 21, training accuracy 0.987908
# Epoch 22, training accuracy 0.986699
# Epoch 23, training accuracy 0.986699
# Epoch 24, training accuracy 0.986699
# Epoch 25, training accuracy 0.987908
# Epoch 26, training accuracy 0.987908
# Epoch 27, training accuracy 0.989117
# Epoch 28, training accuracy 0.986699
# Epoch 29, training accuracy 0.987908
# Epoch 30, training accuracy 0.989117
# Epoch 31, training accuracy 0.987908
# Epoch 32, training accuracy 0.989117
# Epoch 33, training accuracy 0.989117
# Epoch 34, training accuracy 0.987908
# Epoch 35, training accuracy 0.987908
# Epoch 36, training accuracy 0.987908
# Epoch 37, training accuracy 0.989117
# Epoch 38, training accuracy 0.989117
# Epoch 39, training accuracy 0.989117
# Epoch 40, training accuracy 0.989117
# Epoch 41, training accuracy 0.987908
# Epoch 42, training accuracy 0.989117
# Epoch 43, training accuracy 0.989117
# Epoch 44, training accuracy 0.989117
# Epoch 45, training accuracy 0.987908
# Epoch 46, training accuracy 0.987908
# Epoch 47, training accuracy 0.989117
# Epoch 48, training accuracy 0.986699
# Epoch 49, training accuracy 0.989117
# Epoch 50, training accuracy 0.989117
# 0
# 0
# [1139, 371]
# Final accuracy: 0.794974
#
#
#  Added new category: piano
# Train size: 991
# Test size: 2368
# -------------Training new task: 38--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 368 neurons
# Layer 2: Selecting 1138 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.840565
# Epoch 2, training accuracy 0.894046
# Epoch 3, training accuracy 0.935419
# Epoch 4, training accuracy 0.920283
# Epoch 5, training accuracy 0.931382
# Epoch 6, training accuracy 0.943491
# Epoch 7, training accuracy 0.906155
# Epoch 8, training accuracy 0.958628
# Epoch 9, training accuracy 0.943491
# Epoch 10, training accuracy 0.962664
# Epoch 11, training accuracy 0.935419
# Epoch 12, training accuracy 0.943491
# Epoch 13, training accuracy 0.944501
# Epoch 14, training accuracy 0.944501
# Epoch 15, training accuracy 0.937437
# Epoch 16, training accuracy 0.965691
# Epoch 17, training accuracy 0.967709
# Epoch 18, training accuracy 0.939455
# Epoch 19, training accuracy 0.951564
# Epoch 20, training accuracy 0.958628
# Epoch 21, training accuracy 0.941473
# Epoch 22, training accuracy 0.958628
# Epoch 23, training accuracy 0.964682
# Epoch 24, training accuracy 0.939455
# Epoch 25, training accuracy 0.941473
# Epoch 26, training accuracy 0.960646
# Epoch 27, training accuracy 0.951564
# Epoch 28, training accuracy 0.915237
# Epoch 29, training accuracy 0.954591
# Epoch 30, training accuracy 0.972755
# Epoch 31, training accuracy 0.949546
# Epoch 32, training accuracy 0.954591
# Epoch 33, training accuracy 0.956609
# Epoch 34, training accuracy 0.940464
# Epoch 35, training accuracy 0.910192
# Epoch 36, training accuracy 0.968718
# Epoch 37, training accuracy 0.9556
# Epoch 38, training accuracy 0.921292
# Epoch 39, training accuracy 0.948537
# Epoch 40, training accuracy 0.954591
# Epoch 41, training accuracy 0.9778
# Epoch 42, training accuracy 0.943491
# Epoch 43, training accuracy 0.957619
# Epoch 44, training accuracy 0.964682
# Epoch 45, training accuracy 0.956609
# Epoch 46, training accuracy 0.950555
# Epoch 47, training accuracy 0.931382
# Epoch 48, training accuracy 0.961655
# Epoch 49, training accuracy 0.958628
# Epoch 50, training accuracy 0.959637
# Loss: 1.306941
# Overall accuracy: 0.769426, lesser than threshold
# -----------Started Dynamic Expansion------------
# Epoch 1, training accuracy 0.964682
# Epoch 2, training accuracy 0.9667
# Epoch 3, training accuracy 0.969728
# Epoch 4, training accuracy 0.976791
# Epoch 5, training accuracy 0.980827
# Epoch 6, training accuracy 0.983855
# Epoch 7, training accuracy 0.983855
# Epoch 8, training accuracy 0.982846
# Epoch 9, training accuracy 0.984864
# Epoch 10, training accuracy 0.985873
# Epoch 11, training accuracy 0.984864
# Epoch 12, training accuracy 0.985873
# Epoch 13, training accuracy 0.985873
# Epoch 14, training accuracy 0.985873
# Epoch 15, training accuracy 0.985873
# Epoch 16, training accuracy 0.985873
# Epoch 17, training accuracy 0.985873
# Epoch 18, training accuracy 0.985873
# Epoch 19, training accuracy 0.985873
# Epoch 20, training accuracy 0.984864
# Epoch 21, training accuracy 0.984864
# Epoch 22, training accuracy 0.985873
# Epoch 23, training accuracy 0.985873
# Epoch 24, training accuracy 0.985873
# Epoch 25, training accuracy 0.985873
# Epoch 26, training accuracy 0.985873
# Epoch 27, training accuracy 0.985873
# Epoch 28, training accuracy 0.985873
# Epoch 29, training accuracy 0.985873
# Epoch 30, training accuracy 0.984864
# Epoch 31, training accuracy 0.985873
# Epoch 32, training accuracy 0.985873
# Epoch 33, training accuracy 0.985873
# Epoch 34, training accuracy 0.985873
# Epoch 35, training accuracy 0.985873
# Epoch 36, training accuracy 0.985873
# Epoch 37, training accuracy 0.986882
# Epoch 38, training accuracy 0.984864
# Epoch 39, training accuracy 0.986882
# Epoch 40, training accuracy 0.985873
# Epoch 41, training accuracy 0.986882
# Epoch 42, training accuracy 0.986882
# Epoch 43, training accuracy 0.986882
# Epoch 44, training accuracy 0.987891
# Epoch 45, training accuracy 0.986882
# Epoch 46, training accuracy 0.987891
# Epoch 47, training accuracy 0.986882
# Epoch 48, training accuracy 0.987891
# Epoch 49, training accuracy 0.987891
# Epoch 50, training accuracy 0.986882
# 0
# 0
# [1144, 376]
# Final accuracy: 0.784206
#
#
#  Added new category: monitor
# Train size: 1245
# Test size: 2468
# -------------Training new task: 39--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Layer 3: Selecting 375 neurons
# Layer 2: Selecting 1144 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.878715
# Epoch 2, training accuracy 0.911647
# Epoch 3, training accuracy 0.921285
# Epoch 4, training accuracy 0.944578
# Epoch 5, training accuracy 0.944578
# Epoch 6, training accuracy 0.969478
# Epoch 7, training accuracy 0.926104
# Epoch 8, training accuracy 0.934137
# Epoch 9, training accuracy 0.946185
# Epoch 10, training accuracy 0.953414
# Epoch 11, training accuracy 0.953414
# Epoch 12, training accuracy 0.933333
# Epoch 13, training accuracy 0.949398
# Epoch 14, training accuracy 0.95502
# Epoch 15, training accuracy 0.959036
# Epoch 16, training accuracy 0.945382
# Epoch 17, training accuracy 0.935743
# Epoch 18, training accuracy 0.959036
# Epoch 19, training accuracy 0.964659
# Epoch 20, training accuracy 0.95743
# Epoch 21, training accuracy 0.922892
# Epoch 22, training accuracy 0.963052
# Epoch 23, training accuracy 0.944578
# Epoch 24, training accuracy 0.947791
# Epoch 25, training accuracy 0.941365
# Epoch 26, training accuracy 0.956627
# Epoch 27, training accuracy 0.946988
# Epoch 28, training accuracy 0.95743
# Epoch 29, training accuracy 0.963052
# Epoch 30, training accuracy 0.955823
# Epoch 31, training accuracy 0.946185
# Epoch 32, training accuracy 0.960643
# Epoch 33, training accuracy 0.942972
# Epoch 34, training accuracy 0.955823
# Epoch 35, training accuracy 0.967871
# Epoch 36, training accuracy 0.962249
# Epoch 37, training accuracy 0.942169
# Epoch 38, training accuracy 0.946185
# Epoch 39, training accuracy 0.967068
# Epoch 40, training accuracy 0.941365
# Epoch 41, training accuracy 0.958233
# Epoch 42, training accuracy 0.965462
# Epoch 43, training accuracy 0.95743
# Epoch 44, training accuracy 0.955823
# Epoch 45, training accuracy 0.967871
# Epoch 46, training accuracy 0.944578
# Epoch 47, training accuracy 0.958233
# Epoch 48, training accuracy 0.95502
# Epoch 49, training accuracy 0.953414
# Epoch 50, training accuracy 0.961446
# Loss: 1.358637
# Overall accuracy: 0.776337, lesser than threshold
# -----------Started Dynamic Expansion------------
# Epoch 1, training accuracy 0.971888
# Epoch 2, training accuracy 0.976707
# Epoch 3, training accuracy 0.979116
# Epoch 4, training accuracy 0.981526
# Epoch 5, training accuracy 0.983133
# Epoch 6, training accuracy 0.982329
# Epoch 7, training accuracy 0.983936
# Epoch 8, training accuracy 0.983936
# Epoch 9, training accuracy 0.983936
# Epoch 10, training accuracy 0.983133
# Epoch 11, training accuracy 0.984739
# Epoch 12, training accuracy 0.983936
# Epoch 13, training accuracy 0.983133
# Epoch 14, training accuracy 0.984739
# Epoch 15, training accuracy 0.984739
# Epoch 16, training accuracy 0.983936
# Epoch 17, training accuracy 0.984739
# Epoch 18, training accuracy 0.983133
# Epoch 19, training accuracy 0.985542
# Epoch 20, training accuracy 0.984739
# Epoch 21, training accuracy 0.983936
# Epoch 22, training accuracy 0.984739
# Epoch 23, training accuracy 0.985542
# Epoch 24, training accuracy 0.983936
# Epoch 25, training accuracy 0.984739
# Epoch 26, training accuracy 0.985542
# Epoch 27, training accuracy 0.984739
# Epoch 28, training accuracy 0.985542
# Epoch 29, training accuracy 0.986345
# Epoch 30, training accuracy 0.984739
# Epoch 31, training accuracy 0.984739
# Epoch 32, training accuracy 0.984739
# Epoch 33, training accuracy 0.985542
# Epoch 34, training accuracy 0.985542
# Epoch 35, training accuracy 0.986345
# Epoch 36, training accuracy 0.986345
# Epoch 37, training accuracy 0.984739
# Epoch 38, training accuracy 0.986345
# Epoch 39, training accuracy 0.986345
# Epoch 40, training accuracy 0.986345
# Epoch 41, training accuracy 0.984739
# Epoch 42, training accuracy 0.986345
# Epoch 43, training accuracy 0.986345
# Epoch 44, training accuracy 0.986345
# Epoch 45, training accuracy 0.986345
# Epoch 46, training accuracy 0.985542
# Epoch 47, training accuracy 0.986345
# Epoch 48, training accuracy 0.987149
# Epoch 49, training accuracy 0.985542
# Epoch 50, training accuracy 0.986345
# 0
# 0
# [1149, 381]
# Final accuracy: 0.798622
