# %%
#To increase cell width of ipynb
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import tensorflow as tf
from collections import defaultdict
import gzip
import cv2 as cv
import os
import numpy as np
import random
# Out:
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sudhakaran/Desktop/3d_recognition_thesis/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
class DEN():

    def __init__(self):
        self.last_label_index = 0    # tracks the label index upto which the model has been trained
        self.params = dict()
        self.k_ex = 5
        self.den_layers = 3
        self.conv_layers = 2
        tf.reset_default_graph()
        self.sess = None
        self.train = []
        self.train_labels = []
        self.test = []
        self.test_labels = []
        self.batch_size = 10
        self.epochs = 50
        self.early_stop = 5
        self.selected = dict()
        self.lr = 1e-3
        self.l2_mu = 0.001
        self.lamba_regular = 0.7
        self.l1_thr = 0.000001
        self.loss_thr = 0.01

    def extract_data(self):
        train = []
        test = []
        train_labels = []
        test_labels = []
        label_names = []
        
        # For easier disk read operation
        np_train_path = '../ModelNet40/extracted_features/train.npy.gz'
        np_test_path = '../ModelNet40/extracted_features/test.npy.gz'
        np_train_label_path = '../ModelNet40/extracted_features/train_labels.npy'
        np_test_label_path = '../ModelNet40/extracted_features/test_labels.npy'
        np_label_names_path = '../ModelNet40/extracted_features/label_names.npy'
        
        print("\n..........loading dataset from numpy files..........\n")

        with gzip.GzipFile(np_train_path, "r") as f:
            train = np.load(f)
        with gzip.GzipFile(np_test_path, "r") as f:
            test = np.load(f)

        train_labels = np.load(np_train_label_path)
        test_labels = np.load(np_test_label_path)
        label_names = np.load(np_label_names_path)

        return train, train_labels, test, test_labels, label_names


    def add_task(self, task_id, label_names, initial_output=2):

        new_label_indices = []
        self.train = []
        self.train_labels = []
        self.train_ex_labels = []      
 
        if task_id == 1:
            self.new_train = []
            self.new_train_labels = []
            self.new_train_ex_labels = []
            self.total = []
            self.total_ex_labels = []
            self.test = []
            self.test_labels = []
            for i in range(initial_output):   # By default, first task is a binary classification
                new_label_indices.append(i)
            self.last_label_index = i

        else:
            new_label_indices.append(self.last_label_index+1)
            self.last_label_index = self.last_label_index + 1
            
            #saving the old training data
            self.total = self.total + self.new_train
            self.total_ex_labels = self.total_ex_labels + self.new_train_ex_labels
            self.new_train = []
            self.new_train_labels = []
            self.new_train_ex_labels = []

        for index in new_label_indices:
            print(" \n Added new category: "+str(label_names[index]))
            l = 1 if task_id != 1 else index
            for data, label in zip(train_data, train_labels):
                if label_names[index] == label:
                    self.new_train.append(data)
                    self.new_train_labels.append(l)
                    self.new_train_ex_labels.append(index)
                if len(self.new_train_labels) >= 300:
                    break

            for data, label in zip(test_data, test_labels):
                if label_names[index] == label:
                    self.test.append(data)
                    self.test_labels.append(index)
                    
        # ------------------ Random sampling old training data ------------------
#         if task_id != 1:
#             sampled_indices = random.sample(range(len(self.total)), len(self.new_train))
#             for k in sampled_indices:
#                 self.train.append(self.total[k])
#                 self.train_labels.append(0)
#                 self.train_ex_labels.append(self.total_ex_labels[k])
                
#             self.train = self.train + self.new_train
#             self.train_labels = self.train_labels + self.new_train_labels
#             self.train_ex_labels = self.train_ex_labels + self.new_train_ex_labels
#         else:
#             self.train = self.new_train
#             self.train_labels = self.new_train_labels
#             self.train_ex_labels = self.new_train_ex_labels
        
        # ------------------- Memory Replay of old training data ----------------------
        if task_id != 1:
            sample_per_label = int(len(self.new_train) / self.last_label_index)
            if sample_per_label < 20:
                sample_per_label = 20
                
            for index in range(self.last_label_index):
                label_indices = []
                for i, m in enumerate(self.total_ex_labels):
                    if m == index:
                        label_indices.append(i)
                try:
                    sampled_label_indices = random.sample(label_indices, k=sample_per_label)
                except:
                    print("\n Less samples; so taking them all")
                    sampled_label_indices = label_indices
                for k in sampled_label_indices:
                    self.train.append(self.total[k])
                    self.train_labels.append(0)
                    self.train_ex_labels.append(self.total_ex_labels[k])
        else:
            self.train = self.new_train
            self.train_labels = self.new_train_labels
            self.train_ex_labels = self.new_train_ex_labels
            

    def destroy_graph(self):
        tf.reset_default_graph()
        self.params = dict()

    def initialize_parameters(self, output_len=2):
        self.sess = tf.Session()
        self.x = tf.placeholder(tf.float32, [None, 4 * 4 * 512])
        self.y_ = tf.placeholder(tf.float32, [None, output_len])
        # self.keep_prob = tf.placeholder(tf.float32)          # dropout probability

    def create_variable(self, name=None, shape=None, scope=None, trainable=True):
        with tf.variable_scope(scope, reuse=False):
            w = tf.get_variable(name, shape=shape, 
#                                 initializer=tf.random_normal_initializer(mean=0, stddev=1, seed=3),
                                trainable=trainable)
            if "ex" not in name:
                self.params[w.name] = w
        return w

    def get_variable(self, name=None, scope=None):
        with tf.variable_scope(scope, reuse=True):
            w = tf.get_variable(name)
            if "ex" not in name:
                self.params[w.name] = w
        return w

    def restore_params(self, task_id=None, trainable=True, param_values=dict()):
        self.params = dict()
        self.prev_W = dict()
        for scope_name, value in param_values.items():
            self.prev_W[scope_name] = value
            scope_name = scope_name.split(':')[0]
            [scope, name] = scope_name.split('/')

            if task_id != None:
                if ('l%d/w_%d' % (self.den_layers,task_id) in scope_name) or ('l%d/b_%d' % (self.den_layers,task_id) in scope_name):
                    trainable = True
                else:
                    trainable = False

            with tf.variable_scope(scope, reuse=False):
                w = tf.get_variable(name, initializer=value, trainable=trainable)
            self.params[w.name] = w

    def get_params(self):
        vdict = dict()
        for scope_name, ref_w in self.params.items():
            vdict[scope_name] = self.sess.run(ref_w)
        return vdict

    def conv2d(self, x, W):
        return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

    def max_pool_2x2(self, x):
        return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                            strides=[1, 2, 2, 1], padding='SAME')


    def build_model(self, task_id, expansion=False, output_len=2):

        # Note: scope and name values are only given to DEN layers, not for fixed sized layers.

        self.initialize_parameters(output_len)

        if task_id == 1:

            #flattened first fc layer
            W_fc1 = self.create_variable(name="w", shape=[4 * 4 * 512, 1024], scope="l1")   # layer-1 outgoing weight matrix
            b_fc1 = self.create_variable(name="b", shape=[1024], scope="l1")

            h_fc1 = tf.nn.relu(tf.matmul(self.x, W_fc1) + b_fc1)

            #second fc layer
            W_fc2 = self.create_variable(name="w", shape=[1024, 256], scope="l2")   # layer-2 outgoing weight matrix
            b_fc2 = self.create_variable(name="b", shape=[256], scope="l2")

            self.h_fc2 = tf.nn.relu(tf.matmul(h_fc1, W_fc2) + b_fc2)

            # readout fc layer
            self.w_fc = self.create_variable(name="w", shape=[256, output_len], scope="l3")     # layer-3 outgoing weight matrix 
            self.b_fc = self.create_variable(name="b", shape=[output_len], scope="l3")
            y_conv = tf.matmul(self.h_fc2, self.w_fc) + self.b_fc
            
        elif expansion:
            
            # fc layer expansion
            for layer in range(1, self.den_layers+1):

                if layer == 1:
                    w_fc1 = self.get_variable(name="w", scope="l%d"%layer)
                    b_fc1 = self.get_variable(name="b", scope="l%d"%layer)


                    w_expand = self.create_variable(name="w_ex_"+str(task_id),shape=[w_fc1.get_shape().as_list()[0], self.k_ex], scope="l"+str(layer))
                    b_expand = self.create_variable(name="b_ex_"+str(task_id),shape=[self.k_ex], scope="l%d"%layer)
                    w_expanded = tf.concat([w_fc1,w_expand],1)
                    b_expanded = tf.concat([b_fc1,b_expand],0)
                    self.params[w_fc1.name] = w_expanded
                    self.params[b_fc1.name] = b_expanded
                    h_fc1 = tf.nn.relu(tf.matmul(self.x, w_expanded) + b_expanded)

                elif layer == self.den_layers:
                    #weight matrix of current task output
                    w_fc3 = self.get_variable(name="w_%d"%task_id,scope="l%d"%layer)
                    b_fc3 = self.get_variable(name="b_%d"%task_id,scope="l%d"%layer)
                    prev_dim = w_fc3.get_shape().as_list()[0]
                    next_dim = w_fc3.get_shape().as_list()[1]
                    
                    #weight matrix of old tasks output
                    w_fc3_old = self.get_variable(name="w",scope="l%d"%layer)
                    b_fc3_old = self.get_variable(name="b",scope="l%d"%layer)
                    prev_old = w_fc3_old.get_shape().as_list()[0]
                    next_old = w_fc3_old.get_shape().as_list()[1]
                    
                    w_merge = tf.concat([w_fc3_old, w_fc3], 1)
                    b_merge = tf.concat([b_fc3_old, b_fc3], 0)
                    
                    w_expand = self.create_variable(name="w_ex_"+str(task_id), shape=[self.k_ex, next_old+next_dim], scope="l%d"%layer)
                    w_expanded = tf.concat([w_merge, w_expand], 0)
                    
                    self.params[w_fc3_old.name] = w_expanded
                    self.params[b_fc3_old.name] = b_merge
                    
                    y_conv = tf.matmul(self.h_fc2, w_expanded) + b_merge

                else:
                    w_fc2 = self.get_variable(name="w",scope="l%d"%layer)
                    b_fc2 = self.get_variable(name="b",scope="l%d"%layer)

                    prev_dim = w_fc2.get_shape().as_list()[0]
                    next_dim = w_fc2.get_shape().as_list()[1]
                    
                    # Dummy nodes for prev hidden nodes
                    dummy_w = tf.get_variable(name="dummy_t%d_l%d" %(task_id,layer), shape=[self.k_ex, next_dim], 
                                initializer=tf.constant_initializer(0.0), trainable=False)

                    w_expand = self.create_variable(name="w_ex_"+str(task_id), shape=[prev_dim + self.k_ex, self.k_ex], scope="l%d"%layer)
                    b_expand = self.create_variable(name="b_ex_"+str(task_id), shape=[self.k_ex], scope="l%d"%layer)
                    
                    w_fc2_dummy = tf.concat([w_fc2, dummy_w],0)
                    
                    w_expanded = tf.concat([w_fc2_dummy, w_expand], 1)
                    b_expanded = tf.concat([b_fc2, b_expand], 0)
                    
                    self.params[w_fc2.name] = w_expanded
                    self.params[b_fc2.name] = b_expanded
                    self.h_fc2 = tf.nn.relu(tf.matmul(h_fc1, w_expanded) + b_expanded)
                    
        else:

            #flattened first fc layer
            W_fc1 = self.get_variable(name="w", scope="l1")   # layer-1 outgoing weight matrix
            b_fc1 = self.get_variable(name="b", scope="l1")

            h_fc1 = tf.nn.relu(tf.matmul(self.x, W_fc1) + b_fc1)

            #second fc layer
            W_fc2 = self.get_variable(name="w", scope="l2")   # layer-2 outgoing weight matrix
            b_fc2 = self.get_variable(name="b", scope="l2")

            self.h_fc2 = tf.nn.relu(tf.matmul(h_fc1, W_fc2) + b_fc2)

            self.w_fc = self.create_variable(name="w_"+str(task_id), shape=[self.h_fc2.shape[1], output_len], scope="l3", trainable=True)     # layer-3 outgoing weight matrix 
            self.b_fc = self.create_variable(name="b_"+str(task_id), shape=[output_len], scope="l3", trainable=True)
            y_conv = tf.matmul(self.h_fc2, self.w_fc) + self.b_fc

#         y_conv = tf.nn.sigmoid(y_conv)
        return y_conv
    
    def perform_selection(self, task_id, values_dict):      # Breadth first search for selecting non-zero units
        
        all_indices = defaultdict(list)     # to store indices of nonzero units
        selected_params = dict()            # to store values of nonzero units
        selected_prev_params = dict()
        
#         for scope, value in values_dict.items():    # Storing conv layers in selected parameters 
#             if "conv" in scope:
#                 selected_params[scope] = value
            
        for i in reversed(range(1,self.den_layers+1)):
            if i == self.den_layers:
                w = values_dict['l%d/w:0' % i]
                b = values_dict['l%d/b:0' % i]
                w_t = values_dict['l%d/w_%d:0' %(i,task_id)]
                b_t = values_dict['l%d/b_%d:0' %(i,task_id)]
                w = np.concatenate((w, w_t), 1)
                b = np.concatenate((b, b_t), 0)
                for j in range(w.shape[0]):
                    if w[j,-1] <= 0.0001:
                        all_indices['l%d' % i].append(j)
                # np.ix_(): fancy indexing, index with arrays of integers
                # Select non-zero weights between the last hidden layer and the output layer
                selected_params['l%d/w_%d:0' % (i, task_id)] = \
                    w[np.ix_(all_indices['l%d' % i], list(range(w.shape[1])))]
                selected_params['l%d/b_%d:0' % (i, task_id)] = b
                print("\n")
            else:
                w = values_dict['l%d/w:0' % i]
                b = values_dict['l%d/b:0' % i]
                top_indices = all_indices['l%d' % (i + 1)]
                print("Layer %d: Selecting %d neurons" %(i+1, len(top_indices)))
                for j in range(w.shape[0]):
                    if np.count_nonzero(w[j, top_indices] <= 0.0001) != 0 or i == 1:
                        all_indices['l%d' % i].append(j)
                
                # non-zero weights between the layer i and the layer i+1
                sub_weight = w[np.ix_(all_indices['l%d' % i], top_indices)]
                sub_biases = b[all_indices['l%d' % (i + 1)]]
                selected_params['l%d/w:0' % i] = sub_weight
                selected_params['l%d/b:0' % i] = sub_biases
                
                # prev_W : to avoid drastic change in value of weights (Regularization)
                selected_prev_params['l%d/w:0' % i] = \
                    self.prev_W['l%d/w:0' % i][np.ix_(all_indices['l%d' % i], top_indices)]
                selected_prev_params['l%d/b:0' % i] = \
                    self.prev_W['l%d/b:0' % i][all_indices['l%d' % (i + 1)]]

#         for keys, value in selected_params.items():
#             print(keys)
#             print(value)
                
        return [selected_params, selected_prev_params, all_indices]
        
    def build_SR(self, task_id, selected, output_len):    # creating selective retraining model
        
        self.initialize_parameters(output_len)
        h = self.x
        
        for i in range(1, self.den_layers):
            with tf.variable_scope('l%d' % i):
                w = tf.get_variable('w', initializer=selected['l%d/w:0' % i], trainable=True)
                b = tf.get_variable('b', initializer=selected['l%d/b:0' % i], trainable=True)
            h = tf.nn.relu(tf.matmul(h, w) + b)
            
        # last layer
        with tf.variable_scope('l%d' % self.den_layers):
            w = tf.get_variable('w_%d' % task_id,
                                initializer=selected['l%d/w_%d:0' % (self.den_layers, task_id)], trainable=True)
            b = tf.get_variable('b_%d' % task_id,
                                initializer=selected['l%d/b_%d:0' % (self.den_layers, task_id)], trainable=True)

        y_conv = tf.matmul(h, w) + b
#         y_conv = tf.nn.sigmoid(y_conv)
        return y_conv

    def optimization(self, prev_W=None):

        l2_regular = 0
        train_var = []
        regular_terms = []
        
        self.loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=self.y_, logits=y_conv))

#         for var in tf.trainable_variables():
#             l2_regular = l2_regular + tf.nn.l1_loss(var)
#             train_var.append(var)
#         print(len(train_var))

        l1_var = [var for var in tf.trainable_variables()]
        regularizer = tf.contrib.layers.l1_regularizer(self.l2_mu)
        reg_term = tf.contrib.layers.apply_regularization(regularizer, l1_var)
        self.loss = self.loss + reg_term
#         self.loss = self.loss + tf.reduce_mean(self.l2_mu * l2_regular)

        if prev_W != None:
            for var in l1_var:
                if var.name in prev_W.keys():
                    prev_w = prev_W[var.name]
                    regular_terms.append(tf.nn.l2_loss(var - prev_w))
            self.loss = self.loss + self.lamba_regular * tf.reduce_mean(regular_terms)
        
        opt = tf.train.AdamOptimizer(self.lr)
        grads = opt.compute_gradients(self.loss, l1_var)
        apply_grads = opt.apply_gradients(grads)

        correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(self.y_,1))
        self.acc_train = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        
#         l1_var = [var for var in tf.trainable_variables()]
        l1_op_list = []
        with tf.control_dependencies([apply_grads]):  # exec apply_grads first
            for var in tf.trainable_variables():
                th_t = tf.fill(tf.shape(var), tf.convert_to_tensor(self.l1_thr))
                zero_t = tf.zeros(tf.shape(var))
#                 var_temp = var - (th_t * tf.sign(var))
                # [pseudo]:  if |var| < th_t: var = [0];  else: var = var_temp
                l1_op = var.assign(tf.where(tf.less(tf.abs(var), th_t), zero_t, var))
                l1_op_list.append(l1_op)
        
        with tf.control_dependencies(l1_op_list):
            self.train_model = tf.no_op()

    def train_task(self, task_id, batch_size, epochs, retraining=False, expansion=False):

        if task_id == 1:
            task_train_labels = tf.one_hot(indices=np.array(self.train_labels), depth=self.last_label_index+1)
        elif retraining == True or expansion == True:
            task_train_labels = tf.one_hot(indices=np.array(self.train_ex_labels), depth=self.last_label_index+1)
        else:
            task_train_labels = np.array(self.train_labels)
            task_train_labels = task_train_labels.reshape((task_train_labels.shape[0],1))
            task_train_labels = tf.convert_to_tensor(task_train_labels)

        dataset = tf.data.Dataset.from_tensor_slices((np.array(self.train), task_train_labels))
        dataset = dataset.shuffle(len(self.train_ex_labels)).repeat().batch(batch_size)
        iterator = dataset.make_one_shot_iterator()
        (x_data , y_data) = iterator.get_next()

        self.sess.run(tf.global_variables_initializer())
        task_train_labels = self.sess.run(task_train_labels)
        count = 0

#         for scope, ref in self.params.items():
#             if "l2" in scope:
#                 print(self.sess.run(ref))

        for i in range(epochs):

            for j in range(int(len(self.train)/batch_size)):
                x_batch , y_batch = self.sess.run([x_data,y_data])
                _, loss = self.sess.run([self.train_model, self.loss], feed_dict={self.x: x_batch, self.y_: y_batch})

            train_accuracy = self.acc_train.eval(session=self.sess, feed_dict={self.x: self.train, self.y_: task_train_labels})
            print("Epoch %d, training accuracy %g"%(i+1, train_accuracy))

            if train_accuracy == 1:
                count += 1

                if count > 9:
                    print("Best accuracy achieved! \n")
                    break
        
#         for scope, ref in self.params.items():
#             if "l2" in scope:
#                 print(self.sess.run(ref))
        
        return loss
    
    def predict(self, task_id, output_len=2):

        self.initialize_parameters(output_len)

        task_test_labels = tf.one_hot(indices=self.test_labels, depth=self.last_label_index+1)
        task_test_labels = self.sess.run(task_test_labels)
        
        #flattened first fc layer
        W_fc1 = self.get_variable(name="w", scope="l1")   # layer-1 outgoing weight matrix
        b_fc1 = self.get_variable(name="b", scope="l1")

        h_fc1 = tf.nn.relu(tf.matmul(self.x, W_fc1) + b_fc1)

        #second fc layer
        W_fc2 = self.get_variable(name="w", scope="l2")   # layer-2 outgoing weight matrix
        b_fc2 = self.get_variable(name="b", scope="l2")

        self.h_fc2 = tf.nn.relu(tf.matmul(h_fc1, W_fc2) + b_fc2)

        self.w_fc = self.get_variable(name="w", scope="l3")
        self.b_fc = self.get_variable(name="b", scope="l3")

        y_final = tf.matmul(self.h_fc2, self.w_fc) + self.b_fc
        y_final = tf.nn.sigmoid(y_final)
        
        self.sess.run(tf.global_variables_initializer())

        correct_prediction = tf.equal(tf.argmax(y_final,1), tf.argmax(self.y_,1))
        self.acc_test = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        test_accuracy = self.acc_test.eval(session=self.sess, feed_dict={self.x: self.test, self.y_: task_test_labels})
        print("Overall accuracy: %g \n"%test_accuracy)

# %%
if __name__ == "__main__":

    den = DEN()

    train_data, train_labels, test_data, test_labels, label_names = den.extract_data()
    np.random.shuffle(label_names)

# show image using cv
    # print(train_labels[512])
    # cv.imshow("", train_data[512])
    # cv.waitKey(0)

    tf.reset_default_graph()
    task_id = 0
    y_conv = None

    while den.last_label_index != (len(label_names) - 1):     # Loop for adding new tasks (lifelong learning)

        task_id += 1
        den.add_task(task_id, label_names)
        param_values = dict()
        selected = dict()
        print("-------------Training new task: %d--------------"%task_id)
        if task_id == 1:
            y_conv = den.build_model(task_id=task_id)
            den.optimization()
            _ = den.train_task(task_id=task_id, batch_size=den.batch_size, epochs=den.epochs)
            params = den.get_params()
        else:
            print("-----------Started Selective Retraining-------------")
            
            #------------------Selection-------------------
            print("---- Selecting nodes ----")
            y_conv = den.build_model(task_id=task_id, output_len=1)
            den.sess.run(tf.global_variables_initializer())
            params = den.get_params()
            den.optimization()
            
            _ = den.train_task(task_id=task_id, batch_size=den.batch_size, epochs=den.early_stop)
            params = den.get_params()
            if True:           
                [selected, selected_prev, all_indices] = den.perform_selection(task_id=task_id, values_dict=params)
                den.destroy_graph()

                #------------------Retraining-------------------
                print("\n---- Retraining selected nodes ----")
                y_conv = den.build_SR(task_id=task_id, selected=selected, output_len=den.last_label_index+1) 
                den.optimization(prev_W=selected_prev) 
                loss = den.train_task(task_id=task_id, batch_size=den.batch_size, epochs=den.epochs, retraining=True)

                print("Loss: %f"%loss)
            
#             if loss < den.loss_thr:

            
                #--------------Performing Union----------------
                _vars = [(var.name, den.sess.run(var)) for var in tf.trainable_variables() if 'l' in var.name]

                for item in _vars:
                    key, values = item
                    selected[key] = values

                for i in reversed(range(1, den.den_layers+1)):
                    if i == den.den_layers:
                        temp_weight = np.concatenate((params['l%d/w:0' % i], params['l%d/w_%d:0' % (i, task_id)]), axis=1)
                        temp_weight[np.ix_(all_indices['l%d' % i], list(range(den.last_label_index+1)))] = \
                            selected['l%d/w_%d:0' % (i, task_id)]
                        # Updating output matrix structure
                        params['l%d/w:0' % (i)] = temp_weight.tolist()
                        params['l%d/b:0' % (i)] = \
                            selected['l%d/b_%d:0' % (i, task_id)]
                        
#                         params['l%d/w:0' % (i)] = np.concatenate([params['l%d/w:0' % (i)],params['l%d/w_%d:0' % (i,task_id)]], axis=1).tolist()
#                         params['l%d/b:0' % (i)] = np.concatenate([params['l%d/b:0' % (i)],params['l%d/b_%d:0' % (i,task_id)]], axis=0).tolist()
                    else:
                        temp_weight = params['l%d/w:0' % i]
                        temp_biases = params['l%d/b:0' % i]
                        temp_weight[np.ix_(all_indices['l%d' % i], all_indices['l%d' % (i + 1)])] = \
                            selected['l%d/w:0' % i]
                        temp_biases[all_indices['l%d' % (i + 1)]] = \
                            selected['l%d/b:0' % i]
                        params['l%d/w:0' % i] = temp_weight
                        params['l%d/b:0' % i] = temp_biases

            else:
                
                print("\n-----------Started Dynamic Expansion------------")
                den.destroy_graph()
                den.restore_params(task_id=task_id, trainable=False, param_values=params)
                y_conv = den.build_model(task_id=task_id, expansion=True, output_len=den.last_label_index+1)
                den.optimization()
                _ = den.train_task(task_id=task_id, batch_size=den.batch_size, epochs=den.epochs, expansion=True)
                params = den.get_params()
#                 den.k_ex = den.k_ex + 2
#                 print(params)
#                 params['l%d/w:0' % den.den_layers] = np.concatenate([params['l%d/w:0' % den.den_layers],params['l%d/w_%d:0' % (den.den_layers,task_id)]], axis=1).tolist()
#                 params['l%d/b:0' % den.den_layers] = np.concatenate([params['l%d/b:0' % den.den_layers],params['l%d/b_%d:0' % (den.den_layers,task_id)]], axis=0).tolist()

        den.destroy_graph()
        den.restore_params(trainable=False, param_values=params)    # Freezes all learned weights
                    
        # ---------Performance-----------
        den.predict(task_id=task_id, output_len=den.last_label_index+1)
                    
#         param_values = den.get_params()         # Backing-up model weights that were trained upto current task
# Out:
# ..........loading dataset from numpy files..........
#
#
#  Added new category: bench
#
#  Added new category: bookshelf
# -------------Training new task: 1--------------
# Epoch 1, training accuracy 0.986667
# Epoch 2, training accuracy 0.983333
# Epoch 3, training accuracy 0.993333
# Epoch 4, training accuracy 0.993333
# Epoch 5, training accuracy 0.996667
# Epoch 6, training accuracy 0.97
# Epoch 7, training accuracy 0.946667
# Epoch 8, training accuracy 0.996667
# Epoch 9, training accuracy 0.996667
# Epoch 10, training accuracy 1
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 0.963333
# Epoch 13, training accuracy 0.996667
# Epoch 14, training accuracy 0.996667
# Epoch 15, training accuracy 0.996667
# Epoch 16, training accuracy 1
# Epoch 17, training accuracy 1
# Epoch 18, training accuracy 1
# Epoch 19, training accuracy 1
# Epoch 20, training accuracy 1
# Epoch 21, training accuracy 1
# Epoch 22, training accuracy 1
# Epoch 23, training accuracy 0.963333
# Epoch 24, training accuracy 1
# Best accuracy achieved!
#
# Overall accuracy: 0.983333
#
#
#  Added new category: toilet
#
#  Less samples; so taking them all
# -------------Training new task: 2--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 214 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Epoch 6, training accuracy 0.99639
# Epoch 7, training accuracy 1
# Epoch 8, training accuracy 1
# Epoch 9, training accuracy 1
# Epoch 10, training accuracy 0.98556
# Epoch 11, training accuracy 0.99639
# Epoch 12, training accuracy 0.99639
# Epoch 13, training accuracy 1
# Epoch 14, training accuracy 1
# Best accuracy achieved!
#
# Loss: 1.254629
# Overall accuracy: 0.540909
#
#
#  Added new category: lamp
# -------------Training new task: 3--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 163 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.926829
# Epoch 2, training accuracy 0.98374
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Epoch 6, training accuracy 1
# Epoch 7, training accuracy 1
# Epoch 8, training accuracy 1
# Epoch 9, training accuracy 1
# Epoch 10, training accuracy 1
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 1
# Best accuracy achieved!
#
# Loss: 1.199645
# Overall accuracy: 0.883333
#
#
#  Added new category: cone
# -------------Training new task: 4--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 182 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.969512
# Epoch 2, training accuracy 0.981707
# Epoch 3, training accuracy 0.993902
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 0.993902
# Epoch 6, training accuracy 1
# Epoch 7, training accuracy 0.987805
# Epoch 8, training accuracy 0.987805
# Epoch 9, training accuracy 1
# Epoch 10, training accuracy 1
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 0.993902
# Epoch 13, training accuracy 1
# Epoch 14, training accuracy 1
# Epoch 15, training accuracy 1
# Epoch 16, training accuracy 1
# Epoch 17, training accuracy 1
# Best accuracy achieved!
#
# Loss: 1.463627
# Overall accuracy: 0.888462
#
#
#  Added new category: mantel
# -------------Training new task: 5--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 232 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.982143
# Epoch 2, training accuracy 0.985714
# Epoch 3, training accuracy 0.996429
# Epoch 4, training accuracy 0.996429
# Epoch 5, training accuracy 1
# Epoch 6, training accuracy 0.989286
# Epoch 7, training accuracy 0.996429
# Epoch 8, training accuracy 0.996429
# Epoch 9, training accuracy 1
# Epoch 10, training accuracy 0.992857
# Epoch 11, training accuracy 0.996429
# Epoch 12, training accuracy 0.932143
# Epoch 13, training accuracy 1
# Epoch 14, training accuracy 1
# Epoch 15, training accuracy 1
# Epoch 16, training accuracy 1
# Epoch 17, training accuracy 1
# Epoch 18, training accuracy 1
# Epoch 19, training accuracy 0.996429
# Epoch 20, training accuracy 1
# Epoch 21, training accuracy 1
# Best accuracy achieved!
#
# Loss: 1.416090
# Overall accuracy: 0.697222
#
#
#  Added new category: sofa
# -------------Training new task: 6--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 240 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.963333
# Epoch 2, training accuracy 0.956667
# Epoch 3, training accuracy 0.976667
# Epoch 4, training accuracy 0.983333
# Epoch 5, training accuracy 0.976667
# Epoch 6, training accuracy 0.986667
# Epoch 7, training accuracy 0.993333
# Epoch 8, training accuracy 0.986667
# Epoch 9, training accuracy 0.993333
# Epoch 10, training accuracy 0.993333
# Epoch 11, training accuracy 0.996667
# Epoch 12, training accuracy 0.996667
# Epoch 13, training accuracy 0.993333
# Epoch 14, training accuracy 0.916667
# Epoch 15, training accuracy 0.996667
# Epoch 16, training accuracy 0.996667
# Epoch 17, training accuracy 0.986667
# Epoch 18, training accuracy 0.993333
# Epoch 19, training accuracy 0.996667
# Epoch 20, training accuracy 0.98
# Epoch 21, training accuracy 0.996667
# Epoch 22, training accuracy 1
# Epoch 23, training accuracy 0.973333
# Epoch 24, training accuracy 0.986667
# Epoch 25, training accuracy 1
# Epoch 26, training accuracy 1
# Epoch 27, training accuracy 1
# Epoch 28, training accuracy 0.996667
# Epoch 29, training accuracy 0.986667
# Epoch 30, training accuracy 1
# Epoch 31, training accuracy 1
# Epoch 32, training accuracy 0.993333
# Epoch 33, training accuracy 1
# Epoch 34, training accuracy 0.99
# Epoch 35, training accuracy 0.99
# Epoch 36, training accuracy 0.996667
# Epoch 37, training accuracy 1
# Epoch 38, training accuracy 1
# Epoch 39, training accuracy 0.97
# Epoch 40, training accuracy 0.986667
# Epoch 41, training accuracy 0.996667
# Epoch 42, training accuracy 0.976667
# Epoch 43, training accuracy 1
# Best accuracy achieved!
#
# Loss: 1.532152
# Overall accuracy: 0.747826
#
#
#  Added new category: cup
# -------------Training new task: 7--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 176 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.907143
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Epoch 6, training accuracy 1
# Epoch 7, training accuracy 1
# Epoch 8, training accuracy 1
# Epoch 9, training accuracy 1
# Epoch 10, training accuracy 0.978571
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 1
# Best accuracy achieved!
#
# Loss: 1.479753
# Overall accuracy: 0.804167
#
#
#  Added new category: laptop
# -------------Training new task: 8--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 183 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.96875
# Epoch 2, training accuracy 0.975
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
# Epoch 6, training accuracy 1
# Epoch 7, training accuracy 0.99375
# Epoch 8, training accuracy 0.99375
# Epoch 9, training accuracy 1
# Epoch 10, training accuracy 1
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 1
# Epoch 13, training accuracy 0.99375
# Epoch 14, training accuracy 1
# Epoch 15, training accuracy 0.9875
# Epoch 16, training accuracy 0.99375
# Epoch 17, training accuracy 1
# Best accuracy achieved!
#
# Loss: 1.493465
# Overall accuracy: 0.88
#
#
#  Added new category: monitor
# -------------Training new task: 9--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 236 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.824916
# Epoch 2, training accuracy 0.976431
# Epoch 3, training accuracy 0.929293
# Epoch 4, training accuracy 0.969697
# Epoch 5, training accuracy 1
# Epoch 6, training accuracy 0.996633
# Epoch 7, training accuracy 0.996633
# Epoch 8, training accuracy 0.989899
# Epoch 9, training accuracy 0.996633
# Epoch 10, training accuracy 0.959596
# Epoch 11, training accuracy 0.986532
# Epoch 12, training accuracy 0.986532
# Epoch 13, training accuracy 0.973064
# Epoch 14, training accuracy 0.996633
# Epoch 15, training accuracy 0.983165
# Epoch 16, training accuracy 0.986532
# Epoch 17, training accuracy 0.986532
# Epoch 18, training accuracy 0.993266
# Epoch 19, training accuracy 0.993266
# Epoch 20, training accuracy 1
# Epoch 21, training accuracy 1
# Epoch 22, training accuracy 1
# Epoch 23, training accuracy 0.989899
# Epoch 24, training accuracy 0.986532
# Epoch 25, training accuracy 0.969697
# Epoch 26, training accuracy 1
# Epoch 27, training accuracy 0.986532
# Epoch 28, training accuracy 0.979798
# Epoch 29, training accuracy 1
# Epoch 30, training accuracy 0.989899
# Epoch 31, training accuracy 0.996633
# Epoch 32, training accuracy 0.983165
# Epoch 33, training accuracy 0.993266
# Epoch 34, training accuracy 1
# Epoch 35, training accuracy 1
# Epoch 36, training accuracy 0.973064
# Epoch 37, training accuracy 0.983165
# Epoch 38, training accuracy 0.989899
# Epoch 39, training accuracy 0.993266
# Epoch 40, training accuracy 0.969697
# Epoch 41, training accuracy 0.976431
# Epoch 42, training accuracy 0.989899
# Epoch 43, training accuracy 0.996633
# Epoch 44, training accuracy 0.996633
# Epoch 45, training accuracy 1
# Epoch 46, training accuracy 0.996633
# Epoch 47, training accuracy 0.976431
# Epoch 48, training accuracy 1
# Best accuracy achieved!
#
# Loss: 1.568152
# Overall accuracy: 0.755
#
#
#  Added new category: curtain
# -------------Training new task: 10--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 198 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.94
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 0.97
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 0.985
# Epoch 6, training accuracy 1
# Epoch 7, training accuracy 0.99
# Epoch 8, training accuracy 0.995
# Epoch 9, training accuracy 0.975
# Epoch 10, training accuracy 1
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 0.995
# Epoch 13, training accuracy 0.99
# Epoch 14, training accuracy 0.995
# Epoch 15, training accuracy 1
# Epoch 16, training accuracy 1
# Epoch 17, training accuracy 0.99
# Epoch 18, training accuracy 1
# Epoch 19, training accuracy 1
# Epoch 20, training accuracy 0.995
# Epoch 21, training accuracy 1
# Best accuracy achieved!
#
# Loss: 1.429427
# Overall accuracy: 0.767742
#
#
#  Added new category: desk
# -------------Training new task: 11--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 209 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.95
# Epoch 2, training accuracy 0.959091
# Epoch 3, training accuracy 0.986364
# Epoch 4, training accuracy 0.995455
# Epoch 5, training accuracy 0.990909
# Epoch 6, training accuracy 0.995455
# Epoch 7, training accuracy 1
# Epoch 8, training accuracy 0.990909
# Epoch 9, training accuracy 0.995455
# Epoch 10, training accuracy 0.990909
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 0.995455
# Epoch 13, training accuracy 1
# Epoch 14, training accuracy 1
# Epoch 15, training accuracy 0.995455
# Epoch 16, training accuracy 0.972727
# Epoch 17, training accuracy 0.990909
# Epoch 18, training accuracy 0.995455
# Epoch 19, training accuracy 0.963636
# Epoch 20, training accuracy 1
# Epoch 21, training accuracy 1
# Epoch 22, training accuracy 0.995455
# Epoch 23, training accuracy 0.995455
# Epoch 24, training accuracy 1
# Epoch 25, training accuracy 1
# Epoch 26, training accuracy 1
# Epoch 27, training accuracy 1
# Best accuracy achieved!
#
# Loss: 1.532759
# Overall accuracy: 0.788952
#
#
#  Added new category: dresser
# -------------Training new task: 12--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 213 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.9125
# Epoch 2, training accuracy 0.941667
# Epoch 3, training accuracy 0.9625
# Epoch 4, training accuracy 0.95
# Epoch 5, training accuracy 0.991667
# Epoch 6, training accuracy 0.979167
# Epoch 7, training accuracy 0.970833
# Epoch 8, training accuracy 0.983333
# Epoch 9, training accuracy 0.954167
# Epoch 10, training accuracy 0.991667
# Epoch 11, training accuracy 0.975
# Epoch 12, training accuracy 0.983333
# Epoch 13, training accuracy 0.983333
# Epoch 14, training accuracy 0.975
# Epoch 15, training accuracy 0.966667
# Epoch 16, training accuracy 0.966667
# Epoch 17, training accuracy 0.975
# Epoch 18, training accuracy 0.979167
# Epoch 19, training accuracy 0.979167
# Epoch 20, training accuracy 0.991667
# Epoch 21, training accuracy 0.995833
# Epoch 22, training accuracy 0.991667
# Epoch 23, training accuracy 1
# Epoch 24, training accuracy 0.995833
# Epoch 25, training accuracy 0.9875
# Epoch 26, training accuracy 0.941667
# Epoch 27, training accuracy 0.9875
# Epoch 28, training accuracy 0.9875
# Epoch 29, training accuracy 0.983333
# Epoch 30, training accuracy 0.9875
# Epoch 31, training accuracy 0.9875
# Epoch 32, training accuracy 0.991667
# Epoch 33, training accuracy 0.966667
# Epoch 34, training accuracy 0.975
# Epoch 35, training accuracy 0.979167
# Epoch 36, training accuracy 0.983333
# Epoch 37, training accuracy 0.995833
# Epoch 38, training accuracy 0.995833
# Epoch 39, training accuracy 0.970833
# Epoch 40, training accuracy 0.970833
# Epoch 41, training accuracy 0.991667
# Epoch 42, training accuracy 0.995833
# Epoch 43, training accuracy 1
# Epoch 44, training accuracy 1
# Epoch 45, training accuracy 1
# Epoch 46, training accuracy 0.991667
# Epoch 47, training accuracy 0.970833
# Epoch 48, training accuracy 0.9625
# Epoch 49, training accuracy 0.9875
# Epoch 50, training accuracy 1
# Loss: 1.638733
# Overall accuracy: 0.765152
#
#
#  Added new category: tent
# -------------Training new task: 13--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 216 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.865385
# Epoch 2, training accuracy 0.930769
# Epoch 3, training accuracy 0.896154
# Epoch 4, training accuracy 0.969231
# Epoch 5, training accuracy 0.919231
# Epoch 6, training accuracy 0.965385
# Epoch 7, training accuracy 0.965385
# Epoch 8, training accuracy 0.965385
# Epoch 9, training accuracy 0.984615
# Epoch 10, training accuracy 0.973077
# Epoch 11, training accuracy 0.984615
# Epoch 12, training accuracy 0.984615
# Epoch 13, training accuracy 0.976923
# Epoch 14, training accuracy 0.992308
# Epoch 15, training accuracy 0.957692
# Epoch 16, training accuracy 0.965385
# Epoch 17, training accuracy 0.980769
# Epoch 18, training accuracy 0.976923
# Epoch 19, training accuracy 0.853846
# Epoch 20, training accuracy 0.911538
# Epoch 21, training accuracy 0.919231
# Epoch 22, training accuracy 0.95
# Epoch 23, training accuracy 0.973077
# Epoch 24, training accuracy 0.992308
# Epoch 25, training accuracy 0.992308
# Epoch 26, training accuracy 0.988462
# Epoch 27, training accuracy 0.973077
# Epoch 28, training accuracy 0.992308
# Epoch 29, training accuracy 0.973077
# Epoch 30, training accuracy 0.992308
# Epoch 31, training accuracy 0.984615
# Epoch 32, training accuracy 0.980769
# Epoch 33, training accuracy 0.988462
# Epoch 34, training accuracy 0.842308
# Epoch 35, training accuracy 0.996154
# Epoch 36, training accuracy 0.996154
# Epoch 37, training accuracy 0.984615
# Epoch 38, training accuracy 0.992308
# Epoch 39, training accuracy 0.976923
# Epoch 40, training accuracy 0.965385
# Epoch 41, training accuracy 0.984615
# Epoch 42, training accuracy 0.992308
# Epoch 43, training accuracy 0.988462
# Epoch 44, training accuracy 0.996154
# Epoch 45, training accuracy 0.988462
# Epoch 46, training accuracy 0.992308
# Epoch 47, training accuracy 0.996154
# Epoch 48, training accuracy 0.996154
# Epoch 49, training accuracy 0.984615
# Epoch 50, training accuracy 0.980769
# Loss: 1.473922
# Overall accuracy: 0.830049
#
#
#  Added new category: bottle
# -------------Training new task: 14--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 224 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.891156
# Epoch 2, training accuracy 0.938776
# Epoch 3, training accuracy 0.962585
# Epoch 4, training accuracy 0.955782
# Epoch 5, training accuracy 0.979592
# Epoch 6, training accuracy 0.97619
# Epoch 7, training accuracy 0.972789
# Epoch 8, training accuracy 0.942177
# Epoch 9, training accuracy 0.97619
# Epoch 10, training accuracy 0.982993
# Epoch 11, training accuracy 0.989796
# Epoch 12, training accuracy 0.959184
# Epoch 13, training accuracy 0.952381
# Epoch 14, training accuracy 0.94898
# Epoch 15, training accuracy 0.921769
# Epoch 16, training accuracy 0.993197
# Epoch 17, training accuracy 0.979592
# Epoch 18, training accuracy 0.979592
# Epoch 19, training accuracy 0.986395
# Epoch 20, training accuracy 0.959184
# Epoch 21, training accuracy 0.97619
# Epoch 22, training accuracy 0.972789
# Epoch 23, training accuracy 0.989796
# Epoch 24, training accuracy 0.965986
# Epoch 25, training accuracy 0.989796
# Epoch 26, training accuracy 1
# Epoch 27, training accuracy 0.989796
# Epoch 28, training accuracy 0.996599
# Epoch 29, training accuracy 0.982993
# Epoch 30, training accuracy 0.982993
# Epoch 31, training accuracy 0.972789
# Epoch 32, training accuracy 0.986395
# Epoch 33, training accuracy 0.986395
# Epoch 34, training accuracy 0.989796
# Epoch 35, training accuracy 0.979592
# Epoch 36, training accuracy 0.969388
# Epoch 37, training accuracy 0.952381
# Epoch 38, training accuracy 0.962585
# Epoch 39, training accuracy 0.97619
# Epoch 40, training accuracy 0.979592
# Epoch 41, training accuracy 0.982993
# Epoch 42, training accuracy 1
# Epoch 43, training accuracy 0.979592
# Epoch 44, training accuracy 0.996599
# Epoch 45, training accuracy 0.955782
# Epoch 46, training accuracy 0.993197
# Epoch 47, training accuracy 1
# Epoch 48, training accuracy 1
# Epoch 49, training accuracy 0.996599
# Epoch 50, training accuracy 0.982993
# Loss: 1.740592
# Overall accuracy: 0.769737
#
#
#  Added new category: car
# -------------Training new task: 15--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 232 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.903333
# Epoch 2, training accuracy 0.96
# Epoch 3, training accuracy 0.986667
# Epoch 4, training accuracy 0.976667
# Epoch 5, training accuracy 0.976667
# Epoch 6, training accuracy 0.97
# Epoch 7, training accuracy 0.983333
# Epoch 8, training accuracy 0.993333
# Epoch 9, training accuracy 0.99
# Epoch 10, training accuracy 0.996667
# Epoch 11, training accuracy 0.973333
# Epoch 12, training accuracy 0.97
# Epoch 13, training accuracy 0.976667
# Epoch 14, training accuracy 0.986667
# Epoch 15, training accuracy 0.98
# Epoch 16, training accuracy 0.99
# Epoch 17, training accuracy 0.993333
# Epoch 18, training accuracy 0.946667
# Epoch 19, training accuracy 0.963333
# Epoch 20, training accuracy 0.993333
# Epoch 21, training accuracy 0.996667
# Epoch 22, training accuracy 0.996667
# Epoch 23, training accuracy 0.993333
# Epoch 24, training accuracy 0.98
# Epoch 25, training accuracy 0.986667
# Epoch 26, training accuracy 0.986667
# Epoch 27, training accuracy 0.986667
# Epoch 28, training accuracy 1
# Epoch 29, training accuracy 0.973333
# Epoch 30, training accuracy 0.97
# Epoch 31, training accuracy 1
# Epoch 32, training accuracy 0.98
# Epoch 33, training accuracy 0.993333
# Epoch 34, training accuracy 0.963333
# Epoch 35, training accuracy 1
# Epoch 36, training accuracy 0.993333
# Epoch 37, training accuracy 0.996667
# Epoch 38, training accuracy 0.963333
# Epoch 39, training accuracy 1
# Epoch 40, training accuracy 0.953333
# Epoch 41, training accuracy 0.946667
# Epoch 42, training accuracy 0.96
# Epoch 43, training accuracy 0.97
# Epoch 44, training accuracy 0.996667
# Epoch 45, training accuracy 0.996667
# Epoch 46, training accuracy 0.993333
# Epoch 47, training accuracy 0.996667
# Epoch 48, training accuracy 0.956667
# Epoch 49, training accuracy 0.983333
# Epoch 50, training accuracy 0.976667
# Loss: 1.653174
# Overall accuracy: 0.784585
#
#
#  Added new category: table
# -------------Training new task: 16--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 231 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.90625
# Epoch 2, training accuracy 0.96875
# Epoch 3, training accuracy 0.98125
# Epoch 4, training accuracy 0.99375
# Epoch 5, training accuracy 0.9875
# Epoch 6, training accuracy 1
# Epoch 7, training accuracy 0.978125
# Epoch 8, training accuracy 1
# Epoch 9, training accuracy 0.996875
# Epoch 10, training accuracy 1
# Epoch 11, training accuracy 1
# Epoch 12, training accuracy 0.996875
# Epoch 13, training accuracy 0.978125
# Epoch 14, training accuracy 0.984375
# Epoch 15, training accuracy 0.996875
# Epoch 16, training accuracy 0.99375
# Epoch 17, training accuracy 0.9875
# Epoch 18, training accuracy 1
# Epoch 19, training accuracy 0.984375
# Epoch 20, training accuracy 0.946875
# Epoch 21, training accuracy 1
# Epoch 22, training accuracy 0.990625
# Epoch 23, training accuracy 0.9875
# Epoch 24, training accuracy 1
# Epoch 25, training accuracy 0.996875
# Epoch 26, training accuracy 0.996875
# Epoch 27, training accuracy 0.996875
# Epoch 28, training accuracy 0.99375
# Epoch 29, training accuracy 0.9875
# Epoch 30, training accuracy 0.9625
# Epoch 31, training accuracy 0.99375
# Epoch 32, training accuracy 1
# Epoch 33, training accuracy 1
# Epoch 34, training accuracy 0.871875
# Epoch 35, training accuracy 0.996875
# Epoch 36, training accuracy 0.996875
# Epoch 37, training accuracy 1
# Best accuracy achieved!
#
# Loss: 1.599813
# Overall accuracy: 0.820144
#
#
#  Added new category: tv_stand
# -------------Training new task: 17--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 221 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.908824
# Epoch 2, training accuracy 0.935294
# Epoch 3, training accuracy 0.979412
# Epoch 4, training accuracy 0.955882
# Epoch 5, training accuracy 0.958824
# Epoch 6, training accuracy 0.991176
# Epoch 7, training accuracy 0.994118
# Epoch 8, training accuracy 0.997059
# Epoch 9, training accuracy 0.991176
# Epoch 10, training accuracy 0.997059
# Epoch 11, training accuracy 0.994118
# Epoch 12, training accuracy 0.997059
# Epoch 13, training accuracy 1
# Epoch 14, training accuracy 0.964706
# Epoch 15, training accuracy 1
# Epoch 16, training accuracy 0.994118
# Epoch 17, training accuracy 0.973529
# Epoch 18, training accuracy 0.985294
# Epoch 19, training accuracy 0.923529
# Epoch 20, training accuracy 0.991176
# Epoch 21, training accuracy 0.988235
# Epoch 22, training accuracy 0.967647
# Epoch 23, training accuracy 0.997059
# Epoch 24, training accuracy 0.994118
# Epoch 25, training accuracy 0.991176
# Epoch 26, training accuracy 1
# Epoch 27, training accuracy 0.988235
# Epoch 28, training accuracy 0.967647
# Epoch 29, training accuracy 0.967647
# Epoch 30, training accuracy 0.982353
# Epoch 31, training accuracy 0.976471
# Epoch 32, training accuracy 0.982353
# Epoch 33, training accuracy 0.985294
# Epoch 34, training accuracy 0.985294
# Epoch 35, training accuracy 1
# Epoch 36, training accuracy 0.991176
# Epoch 37, training accuracy 0.994118
# Epoch 38, training accuracy 0.988235
# Epoch 39, training accuracy 0.988235
# Epoch 40, training accuracy 0.970588
# Epoch 41, training accuracy 0.988235
# Epoch 42, training accuracy 0.991176
# Epoch 43, training accuracy 0.994118
# Epoch 44, training accuracy 0.988235
# Epoch 45, training accuracy 0.932353
# Epoch 46, training accuracy 0.988235
# Epoch 47, training accuracy 0.988235
# Epoch 48, training accuracy 0.985294
# Epoch 49, training accuracy 0.970588
# Epoch 50, training accuracy 0.988235
# Loss: 1.674389
# Overall accuracy: 0.743399
#
#
#  Added new category: night_stand
# -------------Training new task: 18--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 232 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.930556
# Epoch 2, training accuracy 0.958333
# Epoch 3, training accuracy 0.947222
# Epoch 4, training accuracy 0.966667
# Epoch 5, training accuracy 0.925
# Epoch 6, training accuracy 0.961111
# Epoch 7, training accuracy 0.972222
# Epoch 8, training accuracy 0.977778
# Epoch 9, training accuracy 0.977778
# Epoch 10, training accuracy 0.955556
# Epoch 11, training accuracy 0.919444
# Epoch 12, training accuracy 0.961111
# Epoch 13, training accuracy 0.977778
# Epoch 14, training accuracy 0.941667
# Epoch 15, training accuracy 0.983333
# Epoch 16, training accuracy 0.969444
# Epoch 17, training accuracy 0.972222
# Epoch 18, training accuracy 0.955556
# Epoch 19, training accuracy 0.977778
# Epoch 20, training accuracy 0.969444
# Epoch 21, training accuracy 0.972222
# Epoch 22, training accuracy 0.969444
# Epoch 23, training accuracy 0.966667
# Epoch 24, training accuracy 0.972222
# Epoch 25, training accuracy 0.972222
# Epoch 26, training accuracy 0.994444
# Epoch 27, training accuracy 0.944444
# Epoch 28, training accuracy 0.930556
# Epoch 29, training accuracy 0.980556
# Epoch 30, training accuracy 0.983333
# Epoch 31, training accuracy 0.975
# Epoch 32, training accuracy 0.966667
# Epoch 33, training accuracy 0.977778
# Epoch 34, training accuracy 0.844444
# Epoch 35, training accuracy 0.986111
# Epoch 36, training accuracy 0.991667
# Epoch 37, training accuracy 0.991667
# Epoch 38, training accuracy 0.988889
# Epoch 39, training accuracy 0.988889
# Epoch 40, training accuracy 0.966667
# Epoch 41, training accuracy 0.95
# Epoch 42, training accuracy 0.983333
# Epoch 43, training accuracy 0.972222
# Epoch 44, training accuracy 0.952778
# Epoch 45, training accuracy 0.972222
# Epoch 46, training accuracy 0.925
# Epoch 47, training accuracy 0.977778
# Epoch 48, training accuracy 0.977778
# Epoch 49, training accuracy 0.941667
# Epoch 50, training accuracy 0.961111
# Loss: 1.915583
# Overall accuracy: 0.781202
#
#
#  Added new category: bowl
# -------------Training new task: 19--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 234 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.876316
# Epoch 2, training accuracy 0.936842
# Epoch 3, training accuracy 0.957895
# Epoch 4, training accuracy 0.95
# Epoch 5, training accuracy 0.944737
# Epoch 6, training accuracy 0.936842
# Epoch 7, training accuracy 0.957895
# Epoch 8, training accuracy 0.973684
# Epoch 9, training accuracy 0.965789
# Epoch 10, training accuracy 0.960526
# Epoch 11, training accuracy 0.957895
# Epoch 12, training accuracy 0.955263
# Epoch 13, training accuracy 0.965789
# Epoch 14, training accuracy 0.928947
# Epoch 15, training accuracy 0.902632
# Epoch 16, training accuracy 0.973684
# Epoch 17, training accuracy 0.986842
# Epoch 18, training accuracy 0.984211
# Epoch 19, training accuracy 0.971053
# Epoch 20, training accuracy 0.992105
# Epoch 21, training accuracy 0.981579
# Epoch 22, training accuracy 0.892105
# Epoch 23, training accuracy 0.736842
# Epoch 24, training accuracy 0.939474
# Epoch 25, training accuracy 0.960526
# Epoch 26, training accuracy 0.971053
# Epoch 27, training accuracy 0.981579
# Epoch 28, training accuracy 0.963158
# Epoch 29, training accuracy 0.955263
# Epoch 30, training accuracy 0.989474
# Epoch 31, training accuracy 0.976316
# Epoch 32, training accuracy 0.957895
# Epoch 33, training accuracy 0.971053
# Epoch 34, training accuracy 0.978947
# Epoch 35, training accuracy 0.923684
# Epoch 36, training accuracy 0.976316
# Epoch 37, training accuracy 0.965789
# Epoch 38, training accuracy 0.965789
# Epoch 39, training accuracy 0.968421
# Epoch 40, training accuracy 0.902632
# Epoch 41, training accuracy 0.860526
# Epoch 42, training accuracy 0.981579
# Epoch 43, training accuracy 0.994737
# Epoch 44, training accuracy 0.984211
# Epoch 45, training accuracy 0.981579
# Epoch 46, training accuracy 0.978947
# Epoch 47, training accuracy 0.936842
# Epoch 48, training accuracy 0.981579
# Epoch 49, training accuracy 0.973684
# Epoch 50, training accuracy 0.865789
# Loss: 1.618995
# Overall accuracy: 0.697269
#
#
#  Added new category: radio
# -------------Training new task: 20--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 236 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.88
# Epoch 2, training accuracy 0.9525
# Epoch 3, training accuracy 0.9325
# Epoch 4, training accuracy 0.975
# Epoch 5, training accuracy 0.9675
# Epoch 6, training accuracy 0.965
# Epoch 7, training accuracy 0.9725
# Epoch 8, training accuracy 0.975
# Epoch 9, training accuracy 0.9675
# Epoch 10, training accuracy 0.965
# Epoch 11, training accuracy 0.96
# Epoch 12, training accuracy 0.985
# Epoch 13, training accuracy 0.9425
# Epoch 14, training accuracy 0.9875
# Epoch 15, training accuracy 0.8975
# Epoch 16, training accuracy 0.98
# Epoch 17, training accuracy 0.975
# Epoch 18, training accuracy 0.9875
# Epoch 19, training accuracy 0.975
# Epoch 20, training accuracy 0.9775
# Epoch 21, training accuracy 0.965
# Epoch 22, training accuracy 0.965
# Epoch 23, training accuracy 0.9925
# Epoch 24, training accuracy 0.9825
# Epoch 25, training accuracy 0.955
# Epoch 26, training accuracy 0.9825
# Epoch 27, training accuracy 0.99
# Epoch 28, training accuracy 0.9675
# Epoch 29, training accuracy 0.985
# Epoch 30, training accuracy 0.9875
# Epoch 31, training accuracy 0.97
# Epoch 32, training accuracy 0.9775
# Epoch 33, training accuracy 0.9775
# Epoch 34, training accuracy 0.9875
# Epoch 35, training accuracy 0.9025
# Epoch 36, training accuracy 0.9625
# Epoch 37, training accuracy 0.9625
# Epoch 38, training accuracy 0.9925
# Epoch 39, training accuracy 0.9725
# Epoch 40, training accuracy 0.9875
# Epoch 41, training accuracy 0.97
# Epoch 42, training accuracy 0.935
# Epoch 43, training accuracy 0.9775
# Epoch 44, training accuracy 0.97
# Epoch 45, training accuracy 0.9575
# Epoch 46, training accuracy 0.9875
# Epoch 47, training accuracy 0.9825
# Epoch 48, training accuracy 0.965
# Epoch 49, training accuracy 0.965
# Epoch 50, training accuracy 0.98
# Loss: 1.996345
# Overall accuracy: 0.80568
#
#
#  Added new category: wardrobe
# -------------Training new task: 21--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 232 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.830952
# Epoch 2, training accuracy 0.902381
# Epoch 3, training accuracy 0.821429
# Epoch 4, training accuracy 0.916667
# Epoch 5, training accuracy 0.947619
# Epoch 6, training accuracy 0.928571
# Epoch 7, training accuracy 0.911905
# Epoch 8, training accuracy 0.942857
# Epoch 9, training accuracy 0.928571
# Epoch 10, training accuracy 0.957143
# Epoch 11, training accuracy 0.961905
# Epoch 12, training accuracy 0.942857
# Epoch 13, training accuracy 0.964286
# Epoch 14, training accuracy 0.957143
# Epoch 15, training accuracy 0.952381
# Epoch 16, training accuracy 0.919048
# Epoch 17, training accuracy 0.930952
# Epoch 18, training accuracy 0.916667
# Epoch 19, training accuracy 0.930952
# Epoch 20, training accuracy 0.885714
# Epoch 21, training accuracy 0.935714
# Epoch 22, training accuracy 0.966667
# Epoch 23, training accuracy 0.947619
# Epoch 24, training accuracy 0.959524
# Epoch 25, training accuracy 0.971429
# Epoch 26, training accuracy 0.952381
# Epoch 27, training accuracy 0.95
# Epoch 28, training accuracy 0.959524
# Epoch 29, training accuracy 0.961905
# Epoch 30, training accuracy 0.952381
# Epoch 31, training accuracy 0.978571
# Epoch 32, training accuracy 0.980952
# Epoch 33, training accuracy 0.97381
# Epoch 34, training accuracy 0.971429
# Epoch 35, training accuracy 0.930952
# Epoch 36, training accuracy 0.961905
# Epoch 37, training accuracy 0.919048
# Epoch 38, training accuracy 0.961905
# Epoch 39, training accuracy 0.966667
# Epoch 40, training accuracy 0.969048
# Epoch 41, training accuracy 0.938095
# Epoch 42, training accuracy 0.97381
# Epoch 43, training accuracy 0.947619
# Epoch 44, training accuracy 0.983333
# Epoch 45, training accuracy 0.969048
# Epoch 46, training accuracy 0.961905
# Epoch 47, training accuracy 0.911905
# Epoch 48, training accuracy 0.880952
# Epoch 49, training accuracy 0.904762
# Epoch 50, training accuracy 0.964286
# Loss: 1.971560
# Overall accuracy: 0.793078
#
#
#  Added new category: stairs
# -------------Training new task: 22--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 234 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.809091
# Epoch 2, training accuracy 0.813636
# Epoch 3, training accuracy 0.893182
# Epoch 4, training accuracy 0.911364
# Epoch 5, training accuracy 0.931818
# Epoch 6, training accuracy 0.915909
# Epoch 7, training accuracy 0.913636
# Epoch 8, training accuracy 0.922727
# Epoch 9, training accuracy 0.913636
# Epoch 10, training accuracy 0.875
# Epoch 11, training accuracy 0.906818
# Epoch 12, training accuracy 0.947727
# Epoch 13, training accuracy 0.915909
# Epoch 14, training accuracy 0.890909
# Epoch 15, training accuracy 0.888636
# Epoch 16, training accuracy 0.875
# Epoch 17, training accuracy 0.981818
# Epoch 18, training accuracy 0.961364
# Epoch 19, training accuracy 0.945455
# Epoch 20, training accuracy 0.95
# Epoch 21, training accuracy 0.961364
# Epoch 22, training accuracy 0.913636
# Epoch 23, training accuracy 0.961364
# Epoch 24, training accuracy 0.931818
# Epoch 25, training accuracy 0.929545
# Epoch 26, training accuracy 0.856818
# Epoch 27, training accuracy 0.965909
# Epoch 28, training accuracy 0.913636
# Epoch 29, training accuracy 0.961364
# Epoch 30, training accuracy 0.968182
# Epoch 31, training accuracy 0.954545
# Epoch 32, training accuracy 0.970455
# Epoch 33, training accuracy 0.963636
# Epoch 34, training accuracy 0.927273
# Epoch 35, training accuracy 0.906818
# Epoch 36, training accuracy 0.952273
# Epoch 37, training accuracy 0.972727
# Epoch 38, training accuracy 0.965909
# Epoch 39, training accuracy 0.911364
# Epoch 40, training accuracy 0.945455
# Epoch 41, training accuracy 0.956818
# Epoch 42, training accuracy 0.922727
# Epoch 43, training accuracy 0.925
# Epoch 44, training accuracy 0.965909
# Epoch 45, training accuracy 0.965909
# Epoch 46, training accuracy 0.906818
# Epoch 47, training accuracy 0.968182
# Epoch 48, training accuracy 0.943182
# Epoch 49, training accuracy 0.956818
# Epoch 50, training accuracy 0.931818
# Loss: 1.877227
# Overall accuracy: 0.740929
#
#
#  Added new category: airplane
# -------------Training new task: 23--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 231 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.83913
# Epoch 2, training accuracy 0.913043
# Epoch 3, training accuracy 0.930435
# Epoch 4, training accuracy 0.919565
# Epoch 5, training accuracy 0.921739
# Epoch 6, training accuracy 0.913043
# Epoch 7, training accuracy 0.93913
# Epoch 8, training accuracy 0.963043
# Epoch 9, training accuracy 0.923913
# Epoch 10, training accuracy 0.945652
# Epoch 11, training accuracy 0.945652
# Epoch 12, training accuracy 0.980435
# Epoch 13, training accuracy 0.993478
# Epoch 14, training accuracy 0.906522
# Epoch 15, training accuracy 0.95
# Epoch 16, training accuracy 0.986957
# Epoch 17, training accuracy 0.943478
# Epoch 18, training accuracy 0.969565
# Epoch 19, training accuracy 0.945652
# Epoch 20, training accuracy 0.993478
# Epoch 21, training accuracy 0.986957
# Epoch 22, training accuracy 0.917391
# Epoch 23, training accuracy 0.952174
# Epoch 24, training accuracy 0.902174
# Epoch 25, training accuracy 0.967391
# Epoch 26, training accuracy 0.980435
# Epoch 27, training accuracy 0.982609
# Epoch 28, training accuracy 0.956522
# Epoch 29, training accuracy 0.980435
# Epoch 30, training accuracy 0.956522
# Epoch 31, training accuracy 0.973913
# Epoch 32, training accuracy 0.913043
# Epoch 33, training accuracy 0.952174
# Epoch 34, training accuracy 0.984783
# Epoch 35, training accuracy 0.984783
# Epoch 36, training accuracy 0.976087
# Epoch 37, training accuracy 0.978261
# Epoch 38, training accuracy 0.973913
# Epoch 39, training accuracy 0.976087
# Epoch 40, training accuracy 0.936957
# Epoch 41, training accuracy 0.976087
# Epoch 42, training accuracy 0.956522
# Epoch 43, training accuracy 0.976087
# Epoch 44, training accuracy 0.965217
# Epoch 45, training accuracy 0.980435
# Epoch 46, training accuracy 0.991304
# Epoch 47, training accuracy 0.965217
# Epoch 48, training accuracy 0.956522
# Epoch 49, training accuracy 0.991304
# Epoch 50, training accuracy 0.991304
# Loss: 1.817355
# Overall accuracy: 0.741543
#
#
#  Added new category: chair
# -------------Training new task: 24--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 237 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.89375
# Epoch 2, training accuracy 0.933333
# Epoch 3, training accuracy 0.95
# Epoch 4, training accuracy 0.952083
# Epoch 5, training accuracy 0.964583
# Epoch 6, training accuracy 0.935417
# Epoch 7, training accuracy 0.977083
# Epoch 8, training accuracy 0.95625
# Epoch 9, training accuracy 0.977083
# Epoch 10, training accuracy 0.98125
# Epoch 11, training accuracy 0.977083
# Epoch 12, training accuracy 0.983333
# Epoch 13, training accuracy 0.989583
# Epoch 14, training accuracy 0.98125
# Epoch 15, training accuracy 0.922917
# Epoch 16, training accuracy 0.970833
# Epoch 17, training accuracy 0.970833
# Epoch 18, training accuracy 0.979167
# Epoch 19, training accuracy 0.9875
# Epoch 20, training accuracy 0.954167
# Epoch 21, training accuracy 0.985417
# Epoch 22, training accuracy 0.9875
# Epoch 23, training accuracy 0.929167
# Epoch 24, training accuracy 0.9625
# Epoch 25, training accuracy 0.9875
# Epoch 26, training accuracy 0.95625
# Epoch 27, training accuracy 0.895833
# Epoch 28, training accuracy 0.972917
# Epoch 29, training accuracy 0.964583
# Epoch 30, training accuracy 0.966667
# Epoch 31, training accuracy 0.99375
# Epoch 32, training accuracy 0.95
# Epoch 33, training accuracy 0.98125
# Epoch 34, training accuracy 0.991667
# Epoch 35, training accuracy 0.991667
# Epoch 36, training accuracy 0.977083
# Epoch 37, training accuracy 0.985417
# Epoch 38, training accuracy 0.975
# Epoch 39, training accuracy 0.991667
# Epoch 40, training accuracy 0.977083
# Epoch 41, training accuracy 0.983333
# Epoch 42, training accuracy 0.9875
# Epoch 43, training accuracy 0.975
# Epoch 44, training accuracy 0.979167
# Epoch 45, training accuracy 0.991667
# Epoch 46, training accuracy 0.979167
# Epoch 47, training accuracy 0.99375
# Epoch 48, training accuracy 0.966667
# Epoch 49, training accuracy 0.883333
# Epoch 50, training accuracy 0.879167
# Loss: 1.862309
# Overall accuracy: 0.690748
#
#
#  Added new category: guitar
# -------------Training new task: 25--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 234 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.858
# Epoch 2, training accuracy 0.908
# Epoch 3, training accuracy 0.944
# Epoch 4, training accuracy 0.942
# Epoch 5, training accuracy 0.938
# Epoch 6, training accuracy 0.968
# Epoch 7, training accuracy 0.978
# Epoch 8, training accuracy 0.948
# Epoch 9, training accuracy 0.96
# Epoch 10, training accuracy 0.95
# Epoch 11, training accuracy 0.954
# Epoch 12, training accuracy 0.966
# Epoch 13, training accuracy 0.962
# Epoch 14, training accuracy 0.918
# Epoch 15, training accuracy 0.964
# Epoch 16, training accuracy 0.968
# Epoch 17, training accuracy 0.87
# Epoch 18, training accuracy 0.946
# Epoch 19, training accuracy 0.948
# Epoch 20, training accuracy 0.96
# Epoch 21, training accuracy 0.934
# Epoch 22, training accuracy 0.964
# Epoch 23, training accuracy 0.93
# Epoch 24, training accuracy 0.978
# Epoch 25, training accuracy 0.956
# Epoch 26, training accuracy 0.952
# Epoch 27, training accuracy 0.97
# Epoch 28, training accuracy 0.962
# Epoch 29, training accuracy 0.964
# Epoch 30, training accuracy 0.986
# Epoch 31, training accuracy 0.98
# Epoch 32, training accuracy 0.982
# Epoch 33, training accuracy 0.874
# Epoch 34, training accuracy 0.96
# Epoch 35, training accuracy 0.966
# Epoch 36, training accuracy 0.98
# Epoch 37, training accuracy 0.976
# Epoch 38, training accuracy 0.952
# Epoch 39, training accuracy 0.974
# Epoch 40, training accuracy 0.956
# Epoch 41, training accuracy 0.97
# Epoch 42, training accuracy 0.966
# Epoch 43, training accuracy 0.966
# Epoch 44, training accuracy 0.986
# Epoch 45, training accuracy 0.984
# Epoch 46, training accuracy 0.976
# Epoch 47, training accuracy 0.974
# Epoch 48, training accuracy 0.962
# Epoch 49, training accuracy 0.958
# Epoch 50, training accuracy 0.962
# Loss: 2.317055
# Overall accuracy: 0.714541
#
#
#  Added new category: range_hood
# -------------Training new task: 26--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 232 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.884615
# Epoch 2, training accuracy 0.928846
# Epoch 3, training accuracy 0.969231
# Epoch 4, training accuracy 0.963462
# Epoch 5, training accuracy 0.959615
# Epoch 6, training accuracy 0.963462
# Epoch 7, training accuracy 0.911538
# Epoch 8, training accuracy 0.955769
# Epoch 9, training accuracy 0.967308
# Epoch 10, training accuracy 0.986538
# Epoch 11, training accuracy 0.984615
# Epoch 12, training accuracy 0.992308
# Epoch 13, training accuracy 0.973077
# Epoch 14, training accuracy 0.951923
# Epoch 15, training accuracy 0.969231
# Epoch 16, training accuracy 0.976923
# Epoch 17, training accuracy 0.990385
# Epoch 18, training accuracy 0.988462
# Epoch 19, training accuracy 0.986538
# Epoch 20, training accuracy 0.951923
# Epoch 21, training accuracy 0.953846
# Epoch 22, training accuracy 0.965385
# Epoch 23, training accuracy 0.975
# Epoch 24, training accuracy 0.973077
# Epoch 25, training accuracy 0.961538
# Epoch 26, training accuracy 0.975
# Epoch 27, training accuracy 0.976923
# Epoch 28, training accuracy 0.973077
# Epoch 29, training accuracy 0.942308
# Epoch 30, training accuracy 0.965385
# Epoch 31, training accuracy 0.982692
# Epoch 32, training accuracy 0.990385
# Epoch 33, training accuracy 0.923077
# Epoch 34, training accuracy 0.938462
# Epoch 35, training accuracy 0.959615
# Epoch 36, training accuracy 0.984615
# Epoch 37, training accuracy 0.971154
# Epoch 38, training accuracy 0.965385
# Epoch 39, training accuracy 0.934615
# Epoch 40, training accuracy 0.965385
# Epoch 41, training accuracy 0.961538
# Epoch 42, training accuracy 0.992308
# Epoch 43, training accuracy 0.948077
# Epoch 44, training accuracy 0.969231
# Epoch 45, training accuracy 0.963462
# Epoch 46, training accuracy 0.978846
# Epoch 47, training accuracy 0.951923
# Epoch 48, training accuracy 0.976923
# Epoch 49, training accuracy 0.990385
# Epoch 50, training accuracy 0.982692
# Loss: 1.870222
# Overall accuracy: 0.750844
#
#
#  Added new category: door
# -------------Training new task: 27--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 238 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.874074
# Epoch 2, training accuracy 0.888889
# Epoch 3, training accuracy 0.881481
# Epoch 4, training accuracy 0.931481
# Epoch 5, training accuracy 0.925926
# Epoch 6, training accuracy 0.942593
# Epoch 7, training accuracy 0.944444
# Epoch 8, training accuracy 0.940741
# Epoch 9, training accuracy 0.97037
# Epoch 10, training accuracy 0.957407
# Epoch 11, training accuracy 0.940741
# Epoch 12, training accuracy 0.951852
# Epoch 13, training accuracy 0.957407
# Epoch 14, training accuracy 0.901852
# Epoch 15, training accuracy 0.961111
# Epoch 16, training accuracy 0.935185
# Epoch 17, training accuracy 0.985185
# Epoch 18, training accuracy 0.974074
# Epoch 19, training accuracy 0.942593
# Epoch 20, training accuracy 0.97963
# Epoch 21, training accuracy 0.955556
# Epoch 22, training accuracy 0.97037
# Epoch 23, training accuracy 0.957407
# ...
# Overall accuracy: 0.693392
#
#
#  Added new category: stool
# -------------Training new task: 33--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 229 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.825758
# Epoch 2, training accuracy 0.874242
# Epoch 3, training accuracy 0.906061
# Epoch 4, training accuracy 0.875758
# Epoch 5, training accuracy 0.913636
# Epoch 6, training accuracy 0.913636
# Epoch 7, training accuracy 0.881818
# Epoch 8, training accuracy 0.878788
# Epoch 9, training accuracy 0.936364
# Epoch 10, training accuracy 0.956061
# Epoch 11, training accuracy 0.916667
# Epoch 12, training accuracy 0.877273
# Epoch 13, training accuracy 0.94697
# Epoch 14, training accuracy 0.948485
# Epoch 15, training accuracy 0.957576
# Epoch 16, training accuracy 0.940909
# Epoch 17, training accuracy 0.922727
# Epoch 18, training accuracy 0.943939
# Epoch 19, training accuracy 0.919697
# Epoch 20, training accuracy 0.84697
# Epoch 21, training accuracy 0.948485
# Epoch 22, training accuracy 0.927273
# Epoch 23, training accuracy 0.904545
# Epoch 24, training accuracy 0.916667
# Epoch 25, training accuracy 0.909091
# Epoch 26, training accuracy 0.913636
# Epoch 27, training accuracy 0.936364
# Epoch 28, training accuracy 0.956061
# Epoch 29, training accuracy 0.959091
# Epoch 30, training accuracy 0.95303
# Epoch 31, training accuracy 0.943939
# Epoch 32, training accuracy 0.951515
# Epoch 33, training accuracy 0.95
# Epoch 34, training accuracy 0.954545
# Epoch 35, training accuracy 0.913636
# Epoch 36, training accuracy 0.933333
# Epoch 37, training accuracy 0.927273
# Epoch 38, training accuracy 0.875758
# Epoch 39, training accuracy 0.956061
# Epoch 40, training accuracy 0.930303
# Epoch 41, training accuracy 0.945455
# Epoch 42, training accuracy 0.918182
# Epoch 43, training accuracy 0.927273
# Epoch 44, training accuracy 0.954545
# Epoch 45, training accuracy 0.939394
# Epoch 46, training accuracy 0.956061
# Epoch 47, training accuracy 0.922727
# Epoch 48, training accuracy 0.942424
# Epoch 49, training accuracy 0.940909
# Epoch 50, training accuracy 0.951515
# Loss: 2.055836
# Overall accuracy: 0.76564
#
#
#  Added new category: glass_box
# -------------Training new task: 34--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 227 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.819118
# Epoch 2, training accuracy 0.779412
# Epoch 3, training accuracy 0.891176
# Epoch 4, training accuracy 0.863235
# Epoch 5, training accuracy 0.917647
# Epoch 6, training accuracy 0.907353
# Epoch 7, training accuracy 0.908824
# Epoch 8, training accuracy 0.917647
# Epoch 9, training accuracy 0.904412
# Epoch 10, training accuracy 0.805882
# Epoch 11, training accuracy 0.929412
# Epoch 12, training accuracy 0.858824
# Epoch 13, training accuracy 0.923529
# Epoch 14, training accuracy 0.882353
# Epoch 15, training accuracy 0.916176
# Epoch 16, training accuracy 0.958824
# Epoch 17, training accuracy 0.958824
# Epoch 18, training accuracy 0.914706
# Epoch 19, training accuracy 0.914706
# Epoch 20, training accuracy 0.902941
# Epoch 21, training accuracy 0.952941
# Epoch 22, training accuracy 0.952941
# Epoch 23, training accuracy 0.957353
# Epoch 24, training accuracy 0.939706
# Epoch 25, training accuracy 0.944118
# Epoch 26, training accuracy 0.919118
# Epoch 27, training accuracy 0.957353
# Epoch 28, training accuracy 0.898529
# Epoch 29, training accuracy 0.95
# Epoch 30, training accuracy 0.913235
# Epoch 31, training accuracy 0.926471
# Epoch 32, training accuracy 0.895588
# Epoch 33, training accuracy 0.954412
# Epoch 34, training accuracy 0.930882
# Epoch 35, training accuracy 0.930882
# Epoch 36, training accuracy 0.869118
# Epoch 37, training accuracy 0.910294
# Epoch 38, training accuracy 0.941176
# Epoch 39, training accuracy 0.939706
# Epoch 40, training accuracy 0.923529
# Epoch 41, training accuracy 0.925
# Epoch 42, training accuracy 0.914706
# Epoch 43, training accuracy 0.941176
# Epoch 44, training accuracy 0.942647
# Epoch 45, training accuracy 0.877941
# Epoch 46, training accuracy 0.898529
# Epoch 47, training accuracy 0.945588
# Epoch 48, training accuracy 0.939706
# Epoch 49, training accuracy 0.797059
# Epoch 50, training accuracy 0.932353
# Loss: 2.180826
# Overall accuracy: 0.722222
#
#
#  Added new category: bathtub
# -------------Training new task: 35--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 230 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.81
# Epoch 2, training accuracy 0.842857
# Epoch 3, training accuracy 0.912857
# Epoch 4, training accuracy 0.898571
# Epoch 5, training accuracy 0.847143
# Epoch 6, training accuracy 0.91
# Epoch 7, training accuracy 0.918571
# Epoch 8, training accuracy 0.898571
# Epoch 9, training accuracy 0.904286
# Epoch 10, training accuracy 0.93
# Epoch 11, training accuracy 0.897143
# Epoch 12, training accuracy 0.857143
# Epoch 13, training accuracy 0.94
# Epoch 14, training accuracy 0.871429
# Epoch 15, training accuracy 0.871429
# Epoch 16, training accuracy 0.915714
# Epoch 17, training accuracy 0.828571
# Epoch 18, training accuracy 0.931429
# Epoch 19, training accuracy 0.92
# Epoch 20, training accuracy 0.848571
# Epoch 21, training accuracy 0.878571
# Epoch 22, training accuracy 0.905714
# Epoch 23, training accuracy 0.925714
# Epoch 24, training accuracy 0.92
# Epoch 25, training accuracy 0.845714
# Epoch 26, training accuracy 0.908571
# Epoch 27, training accuracy 0.894286
# Epoch 28, training accuracy 0.915714
# Epoch 29, training accuracy 0.834286
# Epoch 30, training accuracy 0.938571
# Epoch 31, training accuracy 0.918571
# Epoch 32, training accuracy 0.892857
# Epoch 33, training accuracy 0.914286
# Epoch 34, training accuracy 0.938571
# Epoch 35, training accuracy 0.877143
# Epoch 36, training accuracy 0.955714
# Epoch 37, training accuracy 0.948571
# Epoch 38, training accuracy 0.91
# Epoch 39, training accuracy 0.904286
# Epoch 40, training accuracy 0.915714
# Epoch 41, training accuracy 0.905714
# Epoch 42, training accuracy 0.931429
# Epoch 43, training accuracy 0.924286
# Epoch 44, training accuracy 0.911429
# Epoch 45, training accuracy 0.932857
# Epoch 46, training accuracy 0.892857
# Epoch 47, training accuracy 0.924286
# Epoch 48, training accuracy 0.935714
# Epoch 49, training accuracy 0.938571
# Epoch 50, training accuracy 0.884286
# Loss: 2.121804
# Overall accuracy: 0.682675
#
#
#  Added new category: piano
# -------------Training new task: 36--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 236 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.822222
# Epoch 2, training accuracy 0.872222
# Epoch 3, training accuracy 0.809722
# Epoch 4, training accuracy 0.904167
# Epoch 5, training accuracy 0.859722
# Epoch 6, training accuracy 0.922222
# Epoch 7, training accuracy 0.909722
# Epoch 8, training accuracy 0.825
# Epoch 9, training accuracy 0.895833
# Epoch 10, training accuracy 0.897222
# Epoch 11, training accuracy 0.923611
# Epoch 12, training accuracy 0.944444
# Epoch 13, training accuracy 0.916667
# Epoch 14, training accuracy 0.934722
# Epoch 15, training accuracy 0.906944
# Epoch 16, training accuracy 0.938889
# Epoch 17, training accuracy 0.938889
# Epoch 18, training accuracy 0.951389
# Epoch 19, training accuracy 0.822222
# Epoch 20, training accuracy 0.909722
# Epoch 21, training accuracy 0.911111
# Epoch 22, training accuracy 0.869444
# Epoch 23, training accuracy 0.925
# Epoch 24, training accuracy 0.926389
# Epoch 25, training accuracy 0.944444
# Epoch 26, training accuracy 0.915278
# Epoch 27, training accuracy 0.926389
# Epoch 28, training accuracy 0.906944
# Epoch 29, training accuracy 0.890278
# Epoch 30, training accuracy 0.955556
# Epoch 31, training accuracy 0.901389
# Epoch 32, training accuracy 0.955556
# Epoch 33, training accuracy 0.85
# Epoch 34, training accuracy 0.830556
# Epoch 35, training accuracy 0.891667
# Epoch 36, training accuracy 0.883333
# Epoch 37, training accuracy 0.9125
# Epoch 38, training accuracy 0.940278
# Epoch 39, training accuracy 0.958333
# Epoch 40, training accuracy 0.894444
# Epoch 41, training accuracy 0.906944
# Epoch 42, training accuracy 0.920833
# Epoch 43, training accuracy 0.886111
# Epoch 44, training accuracy 0.947222
# Epoch 45, training accuracy 0.952778
# Epoch 46, training accuracy 0.947222
# Epoch 47, training accuracy 0.927778
# Epoch 48, training accuracy 0.938889
# Epoch 49, training accuracy 0.948611
# Epoch 50, training accuracy 0.820833
# Loss: 2.729617
# Overall accuracy: 0.671392
#
#
#  Added new category: keyboard
# -------------Training new task: 37--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 232 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.760811
# Epoch 2, training accuracy 0.801351
# Epoch 3, training accuracy 0.751351
# Epoch 4, training accuracy 0.858108
# Epoch 5, training accuracy 0.882432
# Epoch 6, training accuracy 0.855405
# Epoch 7, training accuracy 0.860811
# Epoch 8, training accuracy 0.904054
# Epoch 9, training accuracy 0.877027
# Epoch 10, training accuracy 0.910811
# Epoch 11, training accuracy 0.893243
# Epoch 12, training accuracy 0.877027
# Epoch 13, training accuracy 0.906757
# Epoch 14, training accuracy 0.874324
# Epoch 15, training accuracy 0.904054
# Epoch 16, training accuracy 0.914865
# Epoch 17, training accuracy 0.910811
# Epoch 18, training accuracy 0.895946
# Epoch 19, training accuracy 0.87027
# Epoch 20, training accuracy 0.893243
# Epoch 21, training accuracy 0.908108
# Epoch 22, training accuracy 0.908108
# Epoch 23, training accuracy 0.905405
# Epoch 24, training accuracy 0.904054
# Epoch 25, training accuracy 0.912162
# Epoch 26, training accuracy 0.905405
# Epoch 27, training accuracy 0.912162
# Epoch 28, training accuracy 0.913514
# Epoch 29, training accuracy 0.894595
# Epoch 30, training accuracy 0.912162
# Epoch 31, training accuracy 0.922973
# Epoch 32, training accuracy 0.890541
# Epoch 33, training accuracy 0.837838
# Epoch 34, training accuracy 0.855405
# Epoch 35, training accuracy 0.913514
# Epoch 36, training accuracy 0.922973
# Epoch 37, training accuracy 0.868919
# Epoch 38, training accuracy 0.835135
# Epoch 39, training accuracy 0.92027
# Epoch 40, training accuracy 0.863514
# Epoch 41, training accuracy 0.931081
# Epoch 42, training accuracy 0.843243
# Epoch 43, training accuracy 0.901351
# Epoch 44, training accuracy 0.92027
# Epoch 45, training accuracy 0.867568
# Epoch 46, training accuracy 0.924324
# Epoch 47, training accuracy 0.897297
# Epoch 48, training accuracy 0.910811
# Epoch 49, training accuracy 0.916216
# Epoch 50, training accuracy 0.939189
# Loss: 2.162108
# Overall accuracy: 0.710818
#
#
#  Added new category: xbox
# -------------Training new task: 38--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 231 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.860526
# Epoch 2, training accuracy 0.876316
# Epoch 3, training accuracy 0.911842
# Epoch 4, training accuracy 0.894737
# Epoch 5, training accuracy 0.898684
# Epoch 6, training accuracy 0.872368
# Epoch 7, training accuracy 0.868421
# Epoch 8, training accuracy 0.884211
# Epoch 9, training accuracy 0.927632
# Epoch 10, training accuracy 0.918421
# Epoch 11, training accuracy 0.914474
# Epoch 12, training accuracy 0.898684
# Epoch 13, training accuracy 0.918421
# Epoch 14, training accuracy 0.925
# Epoch 15, training accuracy 0.880263
# Epoch 16, training accuracy 0.906579
# Epoch 17, training accuracy 0.947368
# Epoch 18, training accuracy 0.909211
# Epoch 19, training accuracy 0.894737
# Epoch 20, training accuracy 0.860526
# Epoch 21, training accuracy 0.930263
# Epoch 22, training accuracy 0.884211
# Epoch 23, training accuracy 0.919737
# Epoch 24, training accuracy 0.938158
# Epoch 25, training accuracy 0.896053
# Epoch 26, training accuracy 0.901316
# Epoch 27, training accuracy 0.928947
# Epoch 28, training accuracy 0.932895
# Epoch 29, training accuracy 0.902632
# Epoch 30, training accuracy 0.906579
# Epoch 31, training accuracy 0.934211
# Epoch 32, training accuracy 0.913158
# Epoch 33, training accuracy 0.927632
# Epoch 34, training accuracy 0.898684
# Epoch 35, training accuracy 0.836842
# Epoch 36, training accuracy 0.918421
# Epoch 37, training accuracy 0.896053
# Epoch 38, training accuracy 0.922368
# Epoch 39, training accuracy 0.948684
# Epoch 40, training accuracy 0.948684
# Epoch 41, training accuracy 0.835526
# Epoch 42, training accuracy 0.934211
# Epoch 43, training accuracy 0.859211
# Epoch 44, training accuracy 0.915789
# Epoch 45, training accuracy 0.923684
# Epoch 46, training accuracy 0.935526
# Epoch 47, training accuracy 0.95
# Epoch 48, training accuracy 0.873684
# Epoch 49, training accuracy 0.923684
# Epoch 50, training accuracy 0.911842
# Loss: 2.203667
# Overall accuracy: 0.695524
#
#
#  Added new category: bed
# -------------Training new task: 39--------------
# -----------Started Selective Retraining-------------
# ---- Selecting nodes ----
# Epoch 1, training accuracy 1
# Epoch 2, training accuracy 1
# Epoch 3, training accuracy 1
# Epoch 4, training accuracy 1
# Epoch 5, training accuracy 1
#
#
# Layer 3: Selecting 237 neurons
# Layer 2: Selecting 1024 neurons
#
# ---- Retraining selected nodes ----
# Epoch 1, training accuracy 0.811538
# Epoch 2, training accuracy 0.821795
# Epoch 3, training accuracy 0.876923
# Epoch 4, training accuracy 0.870513
# Epoch 5, training accuracy 0.90641
# Epoch 6, training accuracy 0.919231
# Epoch 7, training accuracy 0.882051
# Epoch 8, training accuracy 0.911538
# Epoch 9, training accuracy 0.910256
# Epoch 10, training accuracy 0.748718
# Epoch 11, training accuracy 0.876923
# Epoch 12, training accuracy 0.894872
# Epoch 13, training accuracy 0.889744
# Epoch 14, training accuracy 0.864103
# Epoch 15, training accuracy 0.879487
# Epoch 16, training accuracy 0.828205
# Epoch 17, training accuracy 0.867949
# Epoch 18, training accuracy 0.887179
# Epoch 19, training accuracy 0.841026
# Epoch 20, training accuracy 0.902564
# Epoch 21, training accuracy 0.875641
# Epoch 22, training accuracy 0.85641
# Epoch 23, training accuracy 0.932051
# Epoch 24, training accuracy 0.876923
# Epoch 25, training accuracy 0.912821
# Epoch 26, training accuracy 0.920513
# Epoch 27, training accuracy 0.882051
# Epoch 28, training accuracy 0.924359
# Epoch 29, training accuracy 0.925641
# Epoch 30, training accuracy 0.892308
# Epoch 31, training accuracy 0.914103
# Epoch 32, training accuracy 0.892308
# Epoch 33, training accuracy 0.925641
# Epoch 34, training accuracy 0.923077
# Epoch 35, training accuracy 0.788462
# Epoch 36, training accuracy 0.884615
# Epoch 37, training accuracy 0.896154
# Epoch 38, training accuracy 0.911538
# Epoch 39, training accuracy 0.926923
# Epoch 40, training accuracy 0.910256
# Epoch 41, training accuracy 0.908974
# Epoch 42, training accuracy 0.883333
# Epoch 43, training accuracy 0.90641
# Epoch 44, training accuracy 0.848718
# Epoch 45, training accuracy 0.928205
# Epoch 46, training accuracy 0.911538
# Epoch 47, training accuracy 0.860256
# Epoch 48, training accuracy 0.905128
# Epoch 49, training accuracy 0.903846
# Epoch 50, training accuracy 0.884615
# Loss: 2.367284
# Overall accuracy: 0.696515
